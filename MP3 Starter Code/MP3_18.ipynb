# %% [markdown]
# # Mini Project 3 Starter Code
#
# This starter code should provide a working example to assist you with parts B through D of MP3. Feel free to use any, all, or none of the code below. Let me know if I have accidentally introduced any bugs!
#
# -- Wesley
# ___

# %% [markdown]
# The only non-standard library used that is not included with the code is ```pandas```. If you don't have this installed in your local environment, uncomment and run the cell below.

# %%
# !pip install pandas

# %% [markdown]
# Now we load in some custom functions and data structures I have provided to help you with the project.
#
# The ```helpers``` file is used to parse the route schedule csv files, and to cut route schedules into their Bus Tasks.
# The ```data_structures``` file contains some custom data structures for Bus Tasks, Bus Runs, Driver Tasks, and Driver Jobs.  I will go over these in more detail in class, but I suggest you open the Python files and explore the functionality yourself.

# %%
from helpers import clean_df_from_schedule, create_bus_task_lists, make_deadhead_calculator 
from data_structures import BusTask, BusRun, DriverTask, DriverJob

# %% [markdown]
# Now let's load in the csv files. You should have your csv files in the same folder as this Jupyter Notebook.

# %%
route_7 = clean_df_from_schedule("MP3_7.csv")
route_18 = clean_df_from_schedule("MP3_18.csv")
route_52 = clean_df_from_schedule("MP3_52.csv")
deadhead = clean_df_from_schedule("MP3_deadheading.csv")

# %% [markdown]
# Each route's schedule is loaded into a ```pandas``` dataframe, which can be accessed in the typical manner. For example, below are the first 8 rows of the Route 7 schedule.

# %%
route_18.head(n=8)
# Out:
#                    0              1                  2                  3  \
# 0     ﻿18 Northbound                                        18 Southbound
# 1  Mountain & Moraga  Berkeley BART  San Pablo & Marin  San Pablo & Marin
# 2            5:21 AM        6:04 AM            6:17 AM            5:15 AM
# 3            5:36 AM        6:19 AM            6:32 AM            5:30 AM
# 4            5:51 AM        6:34 AM            6:47 AM            5:46 AM
# 5            6:06 AM        6:49 AM            7:02 AM            5:57 AM
# 6            6:22 AM        7:05 AM            7:18 AM            6:18 AM
# 7            6:37 AM        7:27 AM            7:40 AM            6:34 AM
#
#                4                  5
# 0
# 1  Berkeley BART  Mountain & Moraga
# 2        5:32 AM            6:10 AM
# 3        5:47 AM            6:25 AM
# 4        6:03 AM            6:41 AM
# 5        6:16 AM            6:56 AM
# 6        6:37 AM            7:17 AM
# 7        6:53 AM            7:33 AM

# %% [markdown]
# Similarly, we can access the deadheading time table.

# %%
deadhead
# Out:
#                              0                     1                  2  \
# 0           ﻿Travel Time (min)  To: Emeryville Depot  To: Berkeley BART
# 1       From: Emeryville Depot                     0                 10
# 2          From: Berkeley BART                    10                  0
# 3         From: Del Norte BART                    17                 14
# 4      From: Mountain & Moraga                    14                 16
# 5      From: San Pablo & Marin                    11                  7
# 6   From: Bancroft & Telegraph                    11                  2
# 7  From: El Cerrito Plaza BART                    14                 11
#
#                     3                      4                      5  \
# 0  To: Del Norte BART  To: Mountain & Moraga  To: San Pablo & Marin
# 1                  18                     14                     10
# 2                  15                     18                      9
# 3                   0                     31                      8
# 4                  28                      0                     20
# 5                   8                     23                      0
# 6                  16                     17                     10
# 7                   6                     27                      5
#
#                           6                          7
# 0  To: Bancroft & Telegraph  To: El Cerrito Plaza BART
# 1                        11                         15
# 2                         3                         12
# 3                        17                          7
# 4                        15                         25
# 5                        10                          5
# 6                         0                         13
# 7                        14                          0

# %% [markdown]
# I've created a function that allows you to easily lookup the deadhead time by simply providing the origin and destination. The ```make_deadhead_calculator``` function takes in the deadhead table an an input.

# %%
# lets use a function that takes in the origin and destination and returns the deadhead time. We'll feed in the deadhead table once to set it up.

deadhead_time = make_deadhead_calculator(deadhead)

# %% [markdown]
# You can then find the deadhead time by entering the origin and destination as strings into the ```deadhead_time``` function. You do *not* need to run ```make_deadhead_calculator``` again. An example of the use of ```deadhead_time``` is provided below.

# %%
deadhead_time("Emeryville Depot", "Berkeley BART")
# Out:
# 10

# %% [markdown]
# # Splitting Route Schedules into Bus Tasks

# %% [markdown]
# The helper function ```create_bus_task_lists``` is used below, which takes in the route schedule dataframes as input and returns a list of Bus Tasks for each route. This function follows the schedule cutting procedure outlined in Flowchart 2.
#
# The output lists of Bus Tasks for each route are sorted by start time. Both Northbound and Southbound Bus Tasks are combined in the same output list.
#
# *Note: All times have been converted to "minutes after midnight". This is because some Bus Tasks end after midnight (see example below).*

# %%
route_7_tasks, route_18_tasks, route_52_tasks = create_bus_task_lists(route_7, route_18, route_52)

# %%
route_tasks = route_7_tasks + route_18_tasks + route_52_tasks
sorted(route_tasks, key=lambda x: x.start_time, reverse=False)
# Out:
# [BusTask(origin='San Pablo & Marin', start_time=315, destination='Mountain & Moraga', end_time=370, time_at_berkeley_BART=332, task_direction='SB', task_duration=55),
#  BusTask(origin='Mountain & Moraga', start_time=321, destination='San Pablo & Marin', end_time=377, time_at_berkeley_BART=364, task_direction='NB', task_duration=56),
#  BusTask(origin='San Pablo & Marin', start_time=330, destination='Mountain & Moraga', end_time=385, time_at_berkeley_BART=347, task_direction='SB', task_duration=55),
#  BusTask(origin='Mountain & Moraga', start_time=336, destination='San Pablo & Marin', end_time=392, time_at_berkeley_BART=379, task_direction='NB', task_duration=56),
#  BusTask(origin='El Cerrito Plaza BART', start_time=342.0, destination='Bancroft & Telegraph', end_time=392.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=50.0),
#  BusTask(origin='San Pablo & Marin', start_time=346, destination='Mountain & Moraga', end_time=401, time_at_berkeley_BART=363, task_direction='SB', task_duration=55),
#  BusTask(origin='Mountain & Moraga', start_time=351, destination='San Pablo & Marin', end_time=407, time_at_berkeley_BART=394, task_direction='NB', task_duration=56),
#  BusTask(origin='San Pablo & Marin', start_time=357, destination='Mountain & Moraga', end_time=416, time_at_berkeley_BART=376, task_direction='SB', task_duration=59),
#  BusTask(origin='Berkeley BART', start_time=360, destination='Del Norte BART', end_time=392, time_at_berkeley_BART=360, task_direction='NB', task_duration=32),
#  BusTask(origin='Bancroft & Telegraph', start_time=360, destination='El Cerrito Plaza BART', end_time=401, time_at_berkeley_BART=None, task_direction='NB', task_duration=41),
#  BusTask(origin='Mountain & Moraga', start_time=366, destination='San Pablo & Marin', end_time=422, time_at_berkeley_BART=409, task_direction='NB', task_duration=56),
#  BusTask(origin='Del Norte BART', start_time=370, destination='Berkeley BART', end_time=404, time_at_berkeley_BART=404, task_direction='SB', task_duration=34),
#  BusTask(origin='San Pablo & Marin', start_time=378, destination='Mountain & Moraga', end_time=437, time_at_berkeley_BART=397, task_direction='SB', task_duration=59),
#  BusTask(origin='Mountain & Moraga', start_time=382, destination='San Pablo & Marin', end_time=438, time_at_berkeley_BART=425, task_direction='NB', task_duration=56),
#  BusTask(origin='Bancroft & Telegraph', start_time=387, destination='El Cerrito Plaza BART', end_time=436, time_at_berkeley_BART=None, task_direction='NB', task_duration=49),
#  BusTask(origin='San Pablo & Marin', start_time=394, destination='Mountain & Moraga', end_time=453, time_at_berkeley_BART=413, task_direction='SB', task_duration=59),
#  BusTask(origin='Berkeley BART', start_time=397, destination='Del Norte BART', end_time=429, time_at_berkeley_BART=397, task_direction='NB', task_duration=32),
#  BusTask(origin='Mountain & Moraga', start_time=397, destination='San Pablo & Marin', end_time=460, time_at_berkeley_BART=447, task_direction='NB', task_duration=63),
#  BusTask(origin='El Cerrito Plaza BART', start_time=397.0, destination='Bancroft & Telegraph', end_time=440.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=43.0),
#  BusTask(origin='Del Norte BART', start_time=405, destination='Berkeley BART', end_time=439, time_at_berkeley_BART=439, task_direction='SB', task_duration=34),
#  BusTask(origin='San Pablo & Marin', start_time=410, destination='Mountain & Moraga', end_time=469, time_at_berkeley_BART=429, task_direction='SB', task_duration=59),
#  BusTask(origin='Mountain & Moraga', start_time=413, destination='San Pablo & Marin', end_time=476, time_at_berkeley_BART=463, task_direction='NB', task_duration=63),
#  BusTask(origin='El Cerrito Plaza BART', start_time=415.0, destination='Bancroft & Telegraph', end_time=458.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=43.0),
#  BusTask(origin='Bancroft & Telegraph', start_time=420, destination='El Cerrito Plaza BART', end_time=461, time_at_berkeley_BART=None, task_direction='NB', task_duration=41),
#  BusTask(origin='El Cerrito Plaza BART', start_time=423.0, destination='Bancroft & Telegraph', end_time=466.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=43.0),
#  BusTask(origin='San Pablo & Marin', start_time=425, destination='Mountain & Moraga', end_time=484, time_at_berkeley_BART=444, task_direction='SB', task_duration=59),
#  BusTask(origin='Mountain & Moraga', start_time=428, destination='San Pablo & Marin', end_time=491, time_at_berkeley_BART=478, task_direction='NB', task_duration=63),
#  BusTask(origin='Del Norte BART', start_time=435, destination='Berkeley BART', end_time=470, time_at_berkeley_BART=470, task_direction='SB', task_duration=35),
#  BusTask(origin='Berkeley BART', start_time=437, destination='Del Norte BART', end_time=470, time_at_berkeley_BART=437, task_direction='NB', task_duration=33),
#  BusTask(origin='Mountain & Moraga', start_time=440, destination='San Pablo & Marin', end_time=503, time_at_berkeley_BART=490, task_direction='NB', task_duration=63),
#  BusTask(origin='San Pablo & Marin', start_time=440, destination='Mountain & Moraga', end_time=499, time_at_berkeley_BART=459, task_direction='SB', task_duration=59),
#  BusTask(origin='San Pablo & Marin', start_time=443, destination='Mountain & Moraga', end_time=517, time_at_berkeley_BART=467, task_direction='SB', task_duration=74),
#  BusTask(origin='El Cerrito Plaza BART', start_time=444.0, destination='Bancroft & Telegraph', end_time=487.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=43.0),
#  BusTask(origin='Mountain & Moraga', start_time=449, destination='San Pablo & Marin', end_time=512, time_at_berkeley_BART=499, task_direction='NB', task_duration=63),
#  BusTask(origin='Bancroft & Telegraph', start_time=450, destination='El Cerrito Plaza BART', end_time=499, time_at_berkeley_BART=None, task_direction='NB', task_duration=49),
#  BusTask(origin='San Pablo & Marin', start_time=458, destination='Mountain & Moraga', end_time=532, time_at_berkeley_BART=482, task_direction='SB', task_duration=74),
#  BusTask(origin='El Cerrito Plaza BART', start_time=458.0, destination='Bancroft & Telegraph', end_time=501.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=43.0),
#  BusTask(origin='Mountain & Moraga', start_time=465, destination='San Pablo & Marin', end_time=534, time_at_berkeley_BART=519, task_direction='NB', task_duration=69),
#  BusTask(origin='El Cerrito Plaza BART', start_time=468.0, destination='Bancroft & Telegraph', end_time=511.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=43.0),
#  BusTask(origin='Berkeley BART', start_time=472, destination='Del Norte BART', end_time=505, time_at_berkeley_BART=472, task_direction='NB', task_duration=33),
#  BusTask(origin='San Pablo & Marin', start_time=473, destination='Mountain & Moraga', end_time=547, time_at_berkeley_BART=497, task_direction='SB', task_duration=74),
#  BusTask(origin='El Cerrito Plaza BART', start_time=478.0, destination='Bancroft & Telegraph', end_time=521.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=43.0),
#  BusTask(origin='Bancroft & Telegraph', start_time=480, destination='El Cerrito Plaza BART', end_time=521, time_at_berkeley_BART=None, task_direction='NB', task_duration=41),
#  BusTask(origin='Mountain & Moraga', start_time=481, destination='San Pablo & Marin', end_time=550, time_at_berkeley_BART=535, task_direction='NB', task_duration=69),
#  BusTask(origin='Del Norte BART', start_time=485, destination='Berkeley BART', end_time=520, time_at_berkeley_BART=520, task_direction='SB', task_duration=35),
#  BusTask(origin='San Pablo & Marin', start_time=488, destination='Mountain & Moraga', end_time=562, time_at_berkeley_BART=512, task_direction='SB', task_duration=74),
#  BusTask(origin='El Cerrito Plaza BART', start_time=488.0, destination='Bancroft & Telegraph', end_time=532.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Mountain & Moraga', start_time=496, destination='San Pablo & Marin', end_time=565, time_at_berkeley_BART=550, task_direction='NB', task_duration=69),
#  BusTask(origin='El Cerrito Plaza BART', start_time=498.0, destination='Bancroft & Telegraph', end_time=542.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=503, destination='Mountain & Moraga', end_time=577, time_at_berkeley_BART=527, task_direction='SB', task_duration=74),
#  BusTask(origin='El Cerrito Plaza BART', start_time=509.0, destination='Bancroft & Telegraph', end_time=553.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Bancroft & Telegraph', start_time=510, destination='El Cerrito Plaza BART', end_time=553, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='Mountain & Moraga', start_time=511, destination='San Pablo & Marin', end_time=580, time_at_berkeley_BART=565, task_direction='NB', task_duration=69),
#  BusTask(origin='Berkeley BART', start_time=513, destination='Del Norte BART', end_time=546, time_at_berkeley_BART=513, task_direction='NB', task_duration=33),
#  BusTask(origin='San Pablo & Marin', start_time=518, destination='Mountain & Moraga', end_time=592, time_at_berkeley_BART=542, task_direction='SB', task_duration=74),
#  BusTask(origin='El Cerrito Plaza BART', start_time=520.0, destination='Bancroft & Telegraph', end_time=564.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Del Norte BART', start_time=525, destination='Berkeley BART', end_time=560, time_at_berkeley_BART=560, task_direction='SB', task_duration=35),
#  BusTask(origin='Mountain & Moraga', start_time=529, destination='San Pablo & Marin', end_time=598, time_at_berkeley_BART=583, task_direction='NB', task_duration=69),
#  BusTask(origin='El Cerrito Plaza BART', start_time=531.0, destination='Bancroft & Telegraph', end_time=575.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=535, destination='Mountain & Moraga', end_time=605, time_at_berkeley_BART=559, task_direction='SB', task_duration=70),
#  BusTask(origin='Bancroft & Telegraph', start_time=540, destination='El Cerrito Plaza BART', end_time=583, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='El Cerrito Plaza BART', start_time=542.0, destination='Bancroft & Telegraph', end_time=586.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Mountain & Moraga', start_time=544, destination='San Pablo & Marin', end_time=613, time_at_berkeley_BART=598, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=550, destination='Mountain & Moraga', end_time=620, time_at_berkeley_BART=574, task_direction='SB', task_duration=70),
#  BusTask(origin='El Cerrito Plaza BART', start_time=553.0, destination='Bancroft & Telegraph', end_time=597.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Berkeley BART', start_time=555, destination='Del Norte BART', end_time=588, time_at_berkeley_BART=555, task_direction='NB', task_duration=33),
#  BusTask(origin='Mountain & Moraga', start_time=559, destination='San Pablo & Marin', end_time=628, time_at_berkeley_BART=613, task_direction='NB', task_duration=69),
#  BusTask(origin='Del Norte BART', start_time=565, destination='Berkeley BART', end_time=600, time_at_berkeley_BART=600, task_direction='SB', task_duration=35),
#  BusTask(origin='San Pablo & Marin', start_time=565, destination='Mountain & Moraga', end_time=635, time_at_berkeley_BART=589, task_direction='SB', task_duration=70),
#  BusTask(origin='El Cerrito Plaza BART', start_time=565.0, destination='Bancroft & Telegraph', end_time=609.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Bancroft & Telegraph', start_time=570, destination='El Cerrito Plaza BART', end_time=613, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='Mountain & Moraga', start_time=574, destination='San Pablo & Marin', end_time=643, time_at_berkeley_BART=627, task_direction='NB', task_duration=69),
#  BusTask(origin='El Cerrito Plaza BART', start_time=577.0, destination='Bancroft & Telegraph', end_time=621.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=580, destination='Mountain & Moraga', end_time=650, time_at_berkeley_BART=604, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=589, destination='San Pablo & Marin', end_time=658, time_at_berkeley_BART=642, task_direction='NB', task_duration=69),
#  BusTask(origin='Berkeley BART', start_time=594, destination='Del Norte BART', end_time=627, time_at_berkeley_BART=594, task_direction='NB', task_duration=33),
#  BusTask(origin='San Pablo & Marin', start_time=594, destination='Mountain & Moraga', end_time=664, time_at_berkeley_BART=618, task_direction='SB', task_duration=70),
#  BusTask(origin='Bancroft & Telegraph', start_time=598, destination='El Cerrito Plaza BART', end_time=641, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='Mountain & Moraga', start_time=604, destination='San Pablo & Marin', end_time=673, time_at_berkeley_BART=657, task_direction='NB', task_duration=69),
#  BusTask(origin='Del Norte BART', start_time=605, destination='Berkeley BART', end_time=640, time_at_berkeley_BART=640, task_direction='SB', task_duration=35),
#  BusTask(origin='El Cerrito Plaza BART', start_time=608.0, destination='Bancroft & Telegraph', end_time=652.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=610, destination='Mountain & Moraga', end_time=680, time_at_berkeley_BART=634, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=617, destination='San Pablo & Marin', end_time=686, time_at_berkeley_BART=670, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=625, destination='Mountain & Moraga', end_time=695, time_at_berkeley_BART=649, task_direction='SB', task_duration=70),
#  BusTask(origin='Bancroft & Telegraph', start_time=630, destination='El Cerrito Plaza BART', end_time=673, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='Mountain & Moraga', start_time=632, destination='San Pablo & Marin', end_time=701, time_at_berkeley_BART=685, task_direction='NB', task_duration=69),
#  BusTask(origin='Berkeley BART', start_time=634, destination='Del Norte BART', end_time=667, time_at_berkeley_BART=634, task_direction='NB', task_duration=33),
#  BusTask(origin='El Cerrito Plaza BART', start_time=638.0, destination='Bancroft & Telegraph', end_time=682.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=640, destination='Mountain & Moraga', end_time=710, time_at_berkeley_BART=664, task_direction='SB', task_duration=70),
#  BusTask(origin='Del Norte BART', start_time=645, destination='Berkeley BART', end_time=680, time_at_berkeley_BART=680, task_direction='SB', task_duration=35),
#  BusTask(origin='Mountain & Moraga', start_time=647, destination='San Pablo & Marin', end_time=716, time_at_berkeley_BART=700, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=655, destination='Mountain & Moraga', end_time=725, time_at_berkeley_BART=679, task_direction='SB', task_duration=70),
#  BusTask(origin='Bancroft & Telegraph', start_time=660, destination='El Cerrito Plaza BART', end_time=703, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='Mountain & Moraga', start_time=662, destination='San Pablo & Marin', end_time=731, time_at_berkeley_BART=715, task_direction='NB', task_duration=69),
#  BusTask(origin='El Cerrito Plaza BART', start_time=668.0, destination='Bancroft & Telegraph', end_time=712.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=670, destination='Mountain & Moraga', end_time=740, time_at_berkeley_BART=694, task_direction='SB', task_duration=70),
#  BusTask(origin='Berkeley BART', start_time=674, destination='Del Norte BART', end_time=707, time_at_berkeley_BART=674, task_direction='NB', task_duration=33),
#  BusTask(origin='Mountain & Moraga', start_time=676, destination='San Pablo & Marin', end_time=745, time_at_berkeley_BART=729, task_direction='NB', task_duration=69),
#  BusTask(origin='Del Norte BART', start_time=685, destination='Berkeley BART', end_time=720, time_at_berkeley_BART=720, task_direction='SB', task_duration=35),
#  BusTask(origin='San Pablo & Marin', start_time=685, destination='Mountain & Moraga', end_time=755, time_at_berkeley_BART=709, task_direction='SB', task_duration=70),
#  BusTask(origin='Bancroft & Telegraph', start_time=690, destination='El Cerrito Plaza BART', end_time=732, time_at_berkeley_BART=None, task_direction='NB', task_duration=42),
#  BusTask(origin='Mountain & Moraga', start_time=692, destination='San Pablo & Marin', end_time=761, time_at_berkeley_BART=745, task_direction='NB', task_duration=69),
#  BusTask(origin='El Cerrito Plaza BART', start_time=698.0, destination='Bancroft & Telegraph', end_time=742.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=699, destination='Mountain & Moraga', end_time=771, time_at_berkeley_BART=722, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=707, destination='San Pablo & Marin', end_time=776, time_at_berkeley_BART=760, task_direction='NB', task_duration=69),
#  BusTask(origin='Berkeley BART', start_time=714, destination='Del Norte BART', end_time=747, time_at_berkeley_BART=714, task_direction='NB', task_duration=33),
#  BusTask(origin='San Pablo & Marin', start_time=714, destination='Mountain & Moraga', end_time=786, time_at_berkeley_BART=737, task_direction='SB', task_duration=72),
#  BusTask(origin='Bancroft & Telegraph', start_time=720, destination='El Cerrito Plaza BART', end_time=762, time_at_berkeley_BART=None, task_direction='NB', task_duration=42),
#  BusTask(origin='Mountain & Moraga', start_time=722, destination='San Pablo & Marin', end_time=791, time_at_berkeley_BART=775, task_direction='NB', task_duration=69),
#  BusTask(origin='Del Norte BART', start_time=725, destination='Berkeley BART', end_time=760, time_at_berkeley_BART=760, task_direction='SB', task_duration=35),
#  BusTask(origin='El Cerrito Plaza BART', start_time=728.0, destination='Bancroft & Telegraph', end_time=772.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=729, destination='Mountain & Moraga', end_time=801, time_at_berkeley_BART=752, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=737, destination='San Pablo & Marin', end_time=806, time_at_berkeley_BART=790, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=744, destination='Mountain & Moraga', end_time=816, time_at_berkeley_BART=767, task_direction='SB', task_duration=72),
#  BusTask(origin='Bancroft & Telegraph', start_time=750, destination='El Cerrito Plaza BART', end_time=792, time_at_berkeley_BART=None, task_direction='NB', task_duration=42),
#  BusTask(origin='Mountain & Moraga', start_time=752, destination='San Pablo & Marin', end_time=821, time_at_berkeley_BART=805, task_direction='NB', task_duration=69),
#  BusTask(origin='Berkeley BART', start_time=754, destination='Del Norte BART', end_time=787, time_at_berkeley_BART=754, task_direction='NB', task_duration=33),
#  BusTask(origin='El Cerrito Plaza BART', start_time=757.0, destination='Bancroft & Telegraph', end_time=801.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=758, destination='Mountain & Moraga', end_time=830, time_at_berkeley_BART=781, task_direction='SB', task_duration=72),
#  BusTask(origin='Del Norte BART', start_time=765, destination='Berkeley BART', end_time=800, time_at_berkeley_BART=800, task_direction='SB', task_duration=35),
#  BusTask(origin='Mountain & Moraga', start_time=767, destination='San Pablo & Marin', end_time=836, time_at_berkeley_BART=820, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=774, destination='Mountain & Moraga', end_time=846, time_at_berkeley_BART=797, task_direction='SB', task_duration=72),
#  BusTask(origin='Bancroft & Telegraph', start_time=780, destination='El Cerrito Plaza BART', end_time=822, time_at_berkeley_BART=None, task_direction='NB', task_duration=42),
#  BusTask(origin='Mountain & Moraga', start_time=783, destination='San Pablo & Marin', end_time=852, time_at_berkeley_BART=836, task_direction='NB', task_duration=69),
#  BusTask(origin='El Cerrito Plaza BART', start_time=787.0, destination='Bancroft & Telegraph', end_time=831.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=789, destination='Mountain & Moraga', end_time=861, time_at_berkeley_BART=812, task_direction='SB', task_duration=72),
#  BusTask(origin='Berkeley BART', start_time=794, destination='Del Norte BART', end_time=827, time_at_berkeley_BART=794, task_direction='NB', task_duration=33),
#  BusTask(origin='Mountain & Moraga', start_time=798, destination='San Pablo & Marin', end_time=867, time_at_berkeley_BART=851, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=804, destination='Mountain & Moraga', end_time=876, time_at_berkeley_BART=827, task_direction='SB', task_duration=72),
#  BusTask(origin='Del Norte BART', start_time=805, destination='Berkeley BART', end_time=840, time_at_berkeley_BART=840, task_direction='SB', task_duration=35),
#  BusTask(origin='Bancroft & Telegraph', start_time=810, destination='El Cerrito Plaza BART', end_time=852, time_at_berkeley_BART=None, task_direction='NB', task_duration=42),
#  BusTask(origin='Mountain & Moraga', start_time=813, destination='San Pablo & Marin', end_time=885, time_at_berkeley_BART=868, task_direction='NB', task_duration=72),
#  BusTask(origin='El Cerrito Plaza BART', start_time=815.0, destination='Bancroft & Telegraph', end_time=859.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=819, destination='Mountain & Moraga', end_time=891, time_at_berkeley_BART=842, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=828, destination='San Pablo & Marin', end_time=900, time_at_berkeley_BART=883, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=834, destination='Mountain & Moraga', end_time=906, time_at_berkeley_BART=857, task_direction='SB', task_duration=72),
#  BusTask(origin='Berkeley BART', start_time=835, destination='Del Norte BART', end_time=868, time_at_berkeley_BART=835, task_direction='NB', task_duration=33),
#  BusTask(origin='Bancroft & Telegraph', start_time=840, destination='El Cerrito Plaza BART', end_time=891, time_at_berkeley_BART=None, task_direction='NB', task_duration=51),
#  BusTask(origin='Mountain & Moraga', start_time=842, destination='San Pablo & Marin', end_time=914, time_at_berkeley_BART=897, task_direction='NB', task_duration=72),
#  BusTask(origin='Del Norte BART', start_time=845, destination='Berkeley BART', end_time=880, time_at_berkeley_BART=880, task_direction='SB', task_duration=35),
#  BusTask(origin='El Cerrito Plaza BART', start_time=845.0, destination='Bancroft & Telegraph', end_time=896.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=51.0),
#  BusTask(origin='San Pablo & Marin', start_time=849, destination='Mountain & Moraga', end_time=921, time_at_berkeley_BART=872, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=858, destination='San Pablo & Marin', end_time=930, time_at_berkeley_BART=913, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=864, destination='Mountain & Moraga', end_time=940, time_at_berkeley_BART=888, task_direction='SB', task_duration=76),
#  BusTask(origin='Bancroft & Telegraph', start_time=872, destination='El Cerrito Plaza BART', end_time=915, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='El Cerrito Plaza BART', start_time=872.0, destination='Bancroft & Telegraph', end_time=923.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=51.0),
#  BusTask(origin='Mountain & Moraga', start_time=873, destination='San Pablo & Marin', end_time=945, time_at_berkeley_BART=928, task_direction='NB', task_duration=72),
#  BusTask(origin='Berkeley BART', start_time=875, destination='Del Norte BART', end_time=908, time_at_berkeley_BART=875, task_direction='NB', task_duration=33),
#  BusTask(origin='San Pablo & Marin', start_time=879, destination='Mountain & Moraga', end_time=955, time_at_berkeley_BART=903, task_direction='SB', task_duration=76),
#  BusTask(origin='Del Norte BART', start_time=885, destination='Berkeley BART', end_time=920, time_at_berkeley_BART=920, task_direction='SB', task_duration=35),
#  BusTask(origin='Mountain & Moraga', start_time=888, destination='San Pablo & Marin', end_time=960, time_at_berkeley_BART=943, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=893, destination='Mountain & Moraga', end_time=969, time_at_berkeley_BART=917, task_direction='SB', task_duration=76),
#  BusTask(origin='Bancroft & Telegraph', start_time=902, destination='El Cerrito Plaza BART', end_time=947, time_at_berkeley_BART=None, task_direction='NB', task_duration=45),
#  BusTask(origin='Mountain & Moraga', start_time=903, destination='San Pablo & Marin', end_time=975, time_at_berkeley_BART=958, task_direction='NB', task_duration=72),
#  BusTask(origin='El Cerrito Plaza BART', start_time=904.0, destination='Bancroft & Telegraph', end_time=948.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=906, destination='Mountain & Moraga', end_time=982, time_at_berkeley_BART=930, task_direction='SB', task_duration=76),
#  BusTask(origin='Berkeley BART', start_time=916, destination='Del Norte BART', end_time=949, time_at_berkeley_BART=916, task_direction='NB', task_duration=33),
#  BusTask(origin='Mountain & Moraga', start_time=918, destination='San Pablo & Marin', end_time=990, time_at_berkeley_BART=973, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=919, destination='Mountain & Moraga', end_time=995, time_at_berkeley_BART=943, task_direction='SB', task_duration=76),
#  BusTask(origin='Del Norte BART', start_time=925, destination='Berkeley BART', end_time=960, time_at_berkeley_BART=960, task_direction='SB', task_duration=35),
#  BusTask(origin='Bancroft & Telegraph', start_time=929, destination='El Cerrito Plaza BART', end_time=974, time_at_berkeley_BART=None, task_direction='NB', task_duration=45),
#  BusTask(origin='Mountain & Moraga', start_time=933, destination='San Pablo & Marin', end_time=1010, time_at_berkeley_BART=991, task_direction='NB', task_duration=77),
#  BusTask(origin='San Pablo & Marin', start_time=935, destination='Mountain & Moraga', end_time=1011, time_at_berkeley_BART=959, task_direction='SB', task_duration=76),
#  BusTask(origin='El Cerrito Plaza BART', start_time=935.0, destination='Bancroft & Telegraph', end_time=979.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Bancroft & Telegraph', start_time=944, destination='El Cerrito Plaza BART', end_time=989, time_at_berkeley_BART=None, task_direction='NB', task_duration=45),
#  BusTask(origin='San Pablo & Marin', start_time=951, destination='Mountain & Moraga', end_time=1030, time_at_berkeley_BART=976, task_direction='SB', task_duration=79),
#  BusTask(origin='Mountain & Moraga', start_time=952, destination='San Pablo & Marin', end_time=1029, time_at_berkeley_BART=1010, task_direction='NB', task_duration=77),
#  BusTask(origin='Bancroft & Telegraph', start_time=954, destination='El Cerrito Plaza BART', end_time=999, time_at_berkeley_BART=None, task_direction='NB', task_duration=45),
#  BusTask(origin='Berkeley BART', start_time=956, destination='Del Norte BART', end_time=989, time_at_berkeley_BART=956, task_direction='NB', task_duration=33),
#  BusTask(origin='Bancroft & Telegraph', start_time=964, destination='El Cerrito Plaza BART', end_time=1009, time_at_berkeley_BART=None, task_direction='NB', task_duration=45),
#  BusTask(origin='Del Norte BART', start_time=965, destination='Berkeley BART', end_time=1000, time_at_berkeley_BART=1000, task_direction='SB', task_duration=35),
#  BusTask(origin='El Cerrito Plaza BART', start_time=965.0, destination='Bancroft & Telegraph', end_time=1009.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=966, destination='Mountain & Moraga', end_time=1045, time_at_berkeley_BART=991, task_direction='SB', task_duration=79),
#  BusTask(origin='Mountain & Moraga', start_time=967, destination='San Pablo & Marin', end_time=1044, time_at_berkeley_BART=1025, task_direction='NB', task_duration=77),
#  BusTask(origin='Bancroft & Telegraph', start_time=975, destination='El Cerrito Plaza BART', end_time=1020, time_at_berkeley_BART=None, task_direction='NB', task_duration=45),
#  BusTask(origin='Mountain & Moraga', start_time=981, destination='San Pablo & Marin', end_time=1058, time_at_berkeley_BART=1039, task_direction='NB', task_duration=77),
#  BusTask(origin='San Pablo & Marin', start_time=982, destination='Mountain & Moraga', end_time=1061, time_at_berkeley_BART=1007, task_direction='SB', task_duration=79),
#  BusTask(origin='Bancroft & Telegraph', start_time=985, destination='El Cerrito Plaza BART', end_time=1030, time_at_berkeley_BART=None, task_direction='NB', task_duration=45),
#  BusTask(origin='Mountain & Moraga', start_time=994, destination='San Pablo & Marin', end_time=1071, time_at_berkeley_BART=1052, task_direction='NB', task_duration=77),
#  BusTask(origin='Bancroft & Telegraph', start_time=995, destination='El Cerrito Plaza BART', end_time=1039, time_at_berkeley_BART=None, task_direction='NB', task_duration=44),
#  BusTask(origin='El Cerrito Plaza BART', start_time=995.0, destination='Bancroft & Telegraph', end_time=1039.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Berkeley BART', start_time=996, destination='Del Norte BART', end_time=1029, time_at_berkeley_BART=996, task_direction='NB', task_duration=33),
#  BusTask(origin='San Pablo & Marin', start_time=998, destination='Mountain & Moraga', end_time=1077, time_at_berkeley_BART=1023, task_direction='SB', task_duration=79),
#  BusTask(origin='Del Norte BART', start_time=1005, destination='Berkeley BART', end_time=1040, time_at_berkeley_BART=1040, task_direction='SB', task_duration=35),
#  BusTask(origin='Bancroft & Telegraph', start_time=1005, destination='El Cerrito Plaza BART', end_time=1049, time_at_berkeley_BART=None, task_direction='NB', task_duration=44),
#  BusTask(origin='Mountain & Moraga', start_time=1007, destination='San Pablo & Marin', end_time=1080, time_at_berkeley_BART=1063, task_direction='NB', task_duration=73),
#  BusTask(origin='San Pablo & Marin', start_time=1013, destination='Mountain & Moraga', end_time=1092, time_at_berkeley_BART=1038, task_direction='SB', task_duration=79),
#  BusTask(origin='Bancroft & Telegraph', start_time=1015, destination='El Cerrito Plaza BART', end_time=1059, time_at_berkeley_BART=None, task_direction='NB', task_duration=44),
#  BusTask(origin='Mountain & Moraga', start_time=1023, destination='San Pablo & Marin', end_time=1096, time_at_berkeley_BART=1079, task_direction='NB', task_duration=73),
#  BusTask(origin='Bancroft & Telegraph', start_time=1025, destination='El Cerrito Plaza BART', end_time=1069, time_at_berkeley_BART=None, task_direction='NB', task_duration=44),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1026.0, destination='Bancroft & Telegraph', end_time=1070.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=1029, destination='Mountain & Moraga', end_time=1108, time_at_berkeley_BART=1054, task_direction='SB', task_duration=79),
#  BusTask(origin='Bancroft & Telegraph', start_time=1035, destination='El Cerrito Plaza BART', end_time=1079, time_at_berkeley_BART=None, task_direction='NB', task_duration=44),
#  BusTask(origin='Berkeley BART', start_time=1037, destination='Del Norte BART', end_time=1070, time_at_berkeley_BART=1037, task_direction='NB', task_duration=33),
#  BusTask(origin='Mountain & Moraga', start_time=1042, destination='San Pablo & Marin', end_time=1115, time_at_berkeley_BART=1098, task_direction='NB', task_duration=73),
#  BusTask(origin='Del Norte BART', start_time=1045, destination='Berkeley BART', end_time=1080, time_at_berkeley_BART=1080, task_direction='SB', task_duration=35),
#  BusTask(origin='San Pablo & Marin', start_time=1045, destination='Mountain & Moraga', end_time=1124, time_at_berkeley_BART=1070, task_direction='SB', task_duration=79),
#  BusTask(origin='Bancroft & Telegraph', start_time=1045, destination='El Cerrito Plaza BART', end_time=1089, time_at_berkeley_BART=None, task_direction='NB', task_duration=44),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1055.0, destination='Bancroft & Telegraph', end_time=1099.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Bancroft & Telegraph', start_time=1056, destination='El Cerrito Plaza BART', end_time=1100, time_at_berkeley_BART=None, task_direction='NB', task_duration=44),
#  BusTask(origin='Mountain & Moraga', start_time=1057, destination='San Pablo & Marin', end_time=1130, time_at_berkeley_BART=1113, task_direction='NB', task_duration=73),
#  BusTask(origin='San Pablo & Marin', start_time=1061, destination='Mountain & Moraga', end_time=1136, time_at_berkeley_BART=1085, task_direction='SB', task_duration=75),
#  BusTask(origin='Bancroft & Telegraph', start_time=1066, destination='El Cerrito Plaza BART', end_time=1110, time_at_berkeley_BART=None, task_direction='NB', task_duration=44),
#  BusTask(origin='Mountain & Moraga', start_time=1073, destination='San Pablo & Marin', end_time=1146, time_at_berkeley_BART=1129, task_direction='NB', task_duration=73),
#  BusTask(origin='Berkeley BART', start_time=1077, destination='Del Norte BART', end_time=1110, time_at_berkeley_BART=1077, task_direction='NB', task_duration=33),
#  BusTask(origin='Bancroft & Telegraph', start_time=1077, destination='El Cerrito Plaza BART', end_time=1121, time_at_berkeley_BART=None, task_direction='NB', task_duration=44),
#  BusTask(origin='San Pablo & Marin', start_time=1083, destination='Mountain & Moraga', end_time=1158, time_at_berkeley_BART=1107, task_direction='SB', task_duration=75),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1085.0, destination='Bancroft & Telegraph', end_time=1129.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Del Norte BART', start_time=1086, destination='Berkeley BART', end_time=1120, time_at_berkeley_BART=1120, task_direction='SB', task_duration=34),
#  BusTask(origin='Mountain & Moraga', start_time=1089, destination='San Pablo & Marin', end_time=1162, time_at_berkeley_BART=1145, task_direction='NB', task_duration=73),
#  BusTask(origin='Bancroft & Telegraph', start_time=1090, destination='El Cerrito Plaza BART', end_time=1133, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='San Pablo & Marin', start_time=1095, destination='Mountain & Moraga', end_time=1170, time_at_berkeley_BART=1119, task_direction='SB', task_duration=75),
#  BusTask(origin='Bancroft & Telegraph', start_time=1100, destination='El Cerrito Plaza BART', end_time=1143, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='Mountain & Moraga', start_time=1104, destination='San Pablo & Marin', end_time=1177, time_at_berkeley_BART=1160, task_direction='NB', task_duration=73),
#  BusTask(origin='Bancroft & Telegraph', start_time=1109, destination='El Cerrito Plaza BART', end_time=1152, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='San Pablo & Marin', start_time=1111, destination='Mountain & Moraga', end_time=1186, time_at_berkeley_BART=1135, task_direction='SB', task_duration=75),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1115.0, destination='Bancroft & Telegraph', end_time=1159.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Berkeley BART', start_time=1117, destination='Del Norte BART', end_time=1149, time_at_berkeley_BART=1117, task_direction='NB', task_duration=32),
#  BusTask(origin='Mountain & Moraga', start_time=1120, destination='San Pablo & Marin', end_time=1185, time_at_berkeley_BART=1170, task_direction='NB', task_duration=65),
#  BusTask(origin='Bancroft & Telegraph', start_time=1120, destination='El Cerrito Plaza BART', end_time=1163, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='Del Norte BART', start_time=1126, destination='Berkeley BART', end_time=1160, time_at_berkeley_BART=1160, task_direction='SB', task_duration=34),
#  BusTask(origin='San Pablo & Marin', start_time=1128, destination='Mountain & Moraga', end_time=1196, time_at_berkeley_BART=1150, task_direction='SB', task_duration=68),
#  BusTask(origin='Bancroft & Telegraph', start_time=1135, destination='El Cerrito Plaza BART', end_time=1178, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='Mountain & Moraga', start_time=1136, destination='San Pablo & Marin', end_time=1201, time_at_berkeley_BART=1186, task_direction='NB', task_duration=65),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1141.0, destination='Bancroft & Telegraph', end_time=1192.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=51.0),
#  BusTask(origin='San Pablo & Marin', start_time=1143, destination='Mountain & Moraga', end_time=1211, time_at_berkeley_BART=1165, task_direction='SB', task_duration=68),
#  BusTask(origin='Mountain & Moraga', start_time=1148, destination='San Pablo & Marin', end_time=1213, time_at_berkeley_BART=1198, task_direction='NB', task_duration=65),
#  BusTask(origin='Bancroft & Telegraph', start_time=1150, destination='El Cerrito Plaza BART', end_time=1201, time_at_berkeley_BART=None, task_direction='NB', task_duration=51),
#  BusTask(origin='Berkeley BART', start_time=1157, destination='Del Norte BART', end_time=1189, time_at_berkeley_BART=1157, task_direction='NB', task_duration=32),
#  BusTask(origin='San Pablo & Marin', start_time=1162, destination='Mountain & Moraga', end_time=1230, time_at_berkeley_BART=1184, task_direction='SB', task_duration=68),
#  BusTask(origin='Bancroft & Telegraph', start_time=1165, destination='El Cerrito Plaza BART', end_time=1208, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='Del Norte BART', start_time=1166, destination='Berkeley BART', end_time=1200, time_at_berkeley_BART=1200, task_direction='SB', task_duration=34),
#  BusTask(origin='Mountain & Moraga', start_time=1170, destination='San Pablo & Marin', end_time=1235, time_at_berkeley_BART=1220, task_direction='NB', task_duration=65),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1174.0, destination='Bancroft & Telegraph', end_time=1225.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=51.0),
#  BusTask(origin='Bancroft & Telegraph', start_time=1179, destination='El Cerrito Plaza BART', end_time=1222, time_at_berkeley_BART=None, task_direction='NB', task_duration=43),
#  BusTask(origin='Mountain & Moraga', start_time=1182, destination='San Pablo & Marin', end_time=1247, time_at_berkeley_BART=1232, task_direction='NB', task_duration=65),
#  BusTask(origin='San Pablo & Marin', start_time=1182, destination='Mountain & Moraga', end_time=1250, time_at_berkeley_BART=1204, task_direction='SB', task_duration=68),
#  BusTask(origin='Berkeley BART', start_time=1194, destination='Del Norte BART', end_time=1226, time_at_berkeley_BART=1194, task_direction='NB', task_duration=32),
#  BusTask(origin='Bancroft & Telegraph', start_time=1198, destination='El Cerrito Plaza BART', end_time=1240, time_at_berkeley_BART=None, task_direction='NB', task_duration=42),
#  BusTask(origin='Del Norte BART', start_time=1200, destination='Berkeley BART', end_time=1234, time_at_berkeley_BART=1234, task_direction='SB', task_duration=34),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1201.0, destination='Bancroft & Telegraph', end_time=1245.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=1202, destination='Mountain & Moraga', end_time=1270, time_at_berkeley_BART=1224, task_direction='SB', task_duration=68),
#  BusTask(origin='Mountain & Moraga', start_time=1208, destination='San Pablo & Marin', end_time=1270, time_at_berkeley_BART=1255, task_direction='NB', task_duration=62),
#  BusTask(origin='Bancroft & Telegraph', start_time=1220, destination='El Cerrito Plaza BART', end_time=1261, time_at_berkeley_BART=None, task_direction='NB', task_duration=41),
#  BusTask(origin='Mountain & Moraga', start_time=1223, destination='San Pablo & Marin', end_time=1285, time_at_berkeley_BART=1270, task_direction='NB', task_duration=62),
#  BusTask(origin='San Pablo & Marin', start_time=1226, destination='Mountain & Moraga', end_time=1291, time_at_berkeley_BART=1248, task_direction='SB', task_duration=65),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1227.0, destination='Bancroft & Telegraph', end_time=1271.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Mountain & Moraga', start_time=1242, destination='San Pablo & Marin', end_time=1304, time_at_berkeley_BART=1289, task_direction='NB', task_duration=62),
#  BusTask(origin='San Pablo & Marin', start_time=1249, destination='Mountain & Moraga', end_time=1314, time_at_berkeley_BART=1271, task_direction='SB', task_duration=65),
#  BusTask(origin='Bancroft & Telegraph', start_time=1251, destination='El Cerrito Plaza BART', end_time=1292, time_at_berkeley_BART=None, task_direction='NB', task_duration=41),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1256.0, destination='Bancroft & Telegraph', end_time=1300.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Mountain & Moraga', start_time=1262, destination='San Pablo & Marin', end_time=1324, time_at_berkeley_BART=1309, task_direction='NB', task_duration=62),
#  BusTask(origin='San Pablo & Marin', start_time=1267, destination='Mountain & Moraga', end_time=1332, time_at_berkeley_BART=1289, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1282, destination='San Pablo & Marin', end_time=1344, time_at_berkeley_BART=1329, task_direction='NB', task_duration=62),
#  BusTask(origin='Bancroft & Telegraph', start_time=1285, destination='El Cerrito Plaza BART', end_time=1326, time_at_berkeley_BART=None, task_direction='NB', task_duration=41),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1286.0, destination='Bancroft & Telegraph', end_time=1330.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='San Pablo & Marin', start_time=1287, destination='Mountain & Moraga', end_time=1352, time_at_berkeley_BART=1309, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1303, destination='San Pablo & Marin', end_time=1365, time_at_berkeley_BART=1350, task_direction='NB', task_duration=62),
#  BusTask(origin='San Pablo & Marin', start_time=1307, destination='Mountain & Moraga', end_time=1372, time_at_berkeley_BART=1329, task_direction='SB', task_duration=65),
#  BusTask(origin='Bancroft & Telegraph', start_time=1315, destination='El Cerrito Plaza BART', end_time=1356, time_at_berkeley_BART=None, task_direction='NB', task_duration=41),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1316.0, destination='Bancroft & Telegraph', end_time=1360.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Mountain & Moraga', start_time=1326, destination='San Pablo & Marin', end_time=1381, time_at_berkeley_BART=1368, task_direction='NB', task_duration=55),
#  BusTask(origin='San Pablo & Marin', start_time=1327, destination='Mountain & Moraga', end_time=1392, time_at_berkeley_BART=1349, task_direction='SB', task_duration=65),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1346.0, destination='Bancroft & Telegraph', end_time=1390.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Bancroft & Telegraph', start_time=1347, destination='El Cerrito Plaza BART', end_time=1388, time_at_berkeley_BART=None, task_direction='NB', task_duration=41),
#  BusTask(origin='Mountain & Moraga', start_time=1356, destination='San Pablo & Marin', end_time=1411, time_at_berkeley_BART=1398, task_direction='NB', task_duration=55),
#  BusTask(origin='San Pablo & Marin', start_time=1357, destination='Mountain & Moraga', end_time=1422, time_at_berkeley_BART=1379, task_direction='SB', task_duration=65),
#  BusTask(origin='El Cerrito Plaza BART', start_time=1378.0, destination='Bancroft & Telegraph', end_time=1422.0, time_at_berkeley_BART=None, task_direction='SB', task_duration=44.0),
#  BusTask(origin='Bancroft & Telegraph', start_time=1381, destination='El Cerrito Plaza BART', end_time=1422, time_at_berkeley_BART=None, task_direction='NB', task_duration=41),
#  BusTask(origin='San Pablo & Marin', start_time=1387, destination='Mountain & Moraga', end_time=1452, time_at_berkeley_BART=1409, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1388, destination='San Pablo & Marin', end_time=1443, time_at_berkeley_BART=1430, task_direction='NB', task_duration=55),
#  BusTask(origin='San Pablo & Marin', start_time=1417, destination='Mountain & Moraga', end_time=1482, time_at_berkeley_BART=1439, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1418, destination='San Pablo & Marin', end_time=1473, time_at_berkeley_BART=1460, task_direction='NB', task_duration=55)]

# %%
# For example, we can access the first five BusTasks for Route 7, sorted by start time. Notice NB and SB tasks are in the same list. 
route_18_tasks[:]
# Out:
# [BusTask(origin='San Pablo & Marin', start_time=315, destination='Mountain & Moraga', end_time=370, time_at_berkeley_BART=332, task_direction='SB', task_duration=55),
#  BusTask(origin='Mountain & Moraga', start_time=321, destination='San Pablo & Marin', end_time=377, time_at_berkeley_BART=364, task_direction='NB', task_duration=56),
#  BusTask(origin='San Pablo & Marin', start_time=330, destination='Mountain & Moraga', end_time=385, time_at_berkeley_BART=347, task_direction='SB', task_duration=55),
#  BusTask(origin='Mountain & Moraga', start_time=336, destination='San Pablo & Marin', end_time=392, time_at_berkeley_BART=379, task_direction='NB', task_duration=56),
#  BusTask(origin='San Pablo & Marin', start_time=346, destination='Mountain & Moraga', end_time=401, time_at_berkeley_BART=363, task_direction='SB', task_duration=55),
#  BusTask(origin='Mountain & Moraga', start_time=351, destination='San Pablo & Marin', end_time=407, time_at_berkeley_BART=394, task_direction='NB', task_duration=56),
#  BusTask(origin='San Pablo & Marin', start_time=357, destination='Mountain & Moraga', end_time=416, time_at_berkeley_BART=376, task_direction='SB', task_duration=59),
#  BusTask(origin='Mountain & Moraga', start_time=366, destination='San Pablo & Marin', end_time=422, time_at_berkeley_BART=409, task_direction='NB', task_duration=56),
#  BusTask(origin='San Pablo & Marin', start_time=378, destination='Mountain & Moraga', end_time=437, time_at_berkeley_BART=397, task_direction='SB', task_duration=59),
#  BusTask(origin='Mountain & Moraga', start_time=382, destination='San Pablo & Marin', end_time=438, time_at_berkeley_BART=425, task_direction='NB', task_duration=56),
#  BusTask(origin='San Pablo & Marin', start_time=394, destination='Mountain & Moraga', end_time=453, time_at_berkeley_BART=413, task_direction='SB', task_duration=59),
#  BusTask(origin='Mountain & Moraga', start_time=397, destination='San Pablo & Marin', end_time=460, time_at_berkeley_BART=447, task_direction='NB', task_duration=63),
#  BusTask(origin='San Pablo & Marin', start_time=410, destination='Mountain & Moraga', end_time=469, time_at_berkeley_BART=429, task_direction='SB', task_duration=59),
#  BusTask(origin='Mountain & Moraga', start_time=413, destination='San Pablo & Marin', end_time=476, time_at_berkeley_BART=463, task_direction='NB', task_duration=63),
#  BusTask(origin='San Pablo & Marin', start_time=425, destination='Mountain & Moraga', end_time=484, time_at_berkeley_BART=444, task_direction='SB', task_duration=59),
#  BusTask(origin='Mountain & Moraga', start_time=428, destination='San Pablo & Marin', end_time=491, time_at_berkeley_BART=478, task_direction='NB', task_duration=63),
#  BusTask(origin='Mountain & Moraga', start_time=440, destination='San Pablo & Marin', end_time=503, time_at_berkeley_BART=490, task_direction='NB', task_duration=63),
#  BusTask(origin='San Pablo & Marin', start_time=440, destination='Mountain & Moraga', end_time=499, time_at_berkeley_BART=459, task_direction='SB', task_duration=59),
#  BusTask(origin='San Pablo & Marin', start_time=443, destination='Mountain & Moraga', end_time=517, time_at_berkeley_BART=467, task_direction='SB', task_duration=74),
#  BusTask(origin='Mountain & Moraga', start_time=449, destination='San Pablo & Marin', end_time=512, time_at_berkeley_BART=499, task_direction='NB', task_duration=63),
#  BusTask(origin='San Pablo & Marin', start_time=458, destination='Mountain & Moraga', end_time=532, time_at_berkeley_BART=482, task_direction='SB', task_duration=74),
#  BusTask(origin='Mountain & Moraga', start_time=465, destination='San Pablo & Marin', end_time=534, time_at_berkeley_BART=519, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=473, destination='Mountain & Moraga', end_time=547, time_at_berkeley_BART=497, task_direction='SB', task_duration=74),
#  BusTask(origin='Mountain & Moraga', start_time=481, destination='San Pablo & Marin', end_time=550, time_at_berkeley_BART=535, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=488, destination='Mountain & Moraga', end_time=562, time_at_berkeley_BART=512, task_direction='SB', task_duration=74),
#  BusTask(origin='Mountain & Moraga', start_time=496, destination='San Pablo & Marin', end_time=565, time_at_berkeley_BART=550, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=503, destination='Mountain & Moraga', end_time=577, time_at_berkeley_BART=527, task_direction='SB', task_duration=74),
#  BusTask(origin='Mountain & Moraga', start_time=511, destination='San Pablo & Marin', end_time=580, time_at_berkeley_BART=565, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=518, destination='Mountain & Moraga', end_time=592, time_at_berkeley_BART=542, task_direction='SB', task_duration=74),
#  BusTask(origin='Mountain & Moraga', start_time=529, destination='San Pablo & Marin', end_time=598, time_at_berkeley_BART=583, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=535, destination='Mountain & Moraga', end_time=605, time_at_berkeley_BART=559, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=544, destination='San Pablo & Marin', end_time=613, time_at_berkeley_BART=598, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=550, destination='Mountain & Moraga', end_time=620, time_at_berkeley_BART=574, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=559, destination='San Pablo & Marin', end_time=628, time_at_berkeley_BART=613, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=565, destination='Mountain & Moraga', end_time=635, time_at_berkeley_BART=589, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=574, destination='San Pablo & Marin', end_time=643, time_at_berkeley_BART=627, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=580, destination='Mountain & Moraga', end_time=650, time_at_berkeley_BART=604, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=589, destination='San Pablo & Marin', end_time=658, time_at_berkeley_BART=642, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=594, destination='Mountain & Moraga', end_time=664, time_at_berkeley_BART=618, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=604, destination='San Pablo & Marin', end_time=673, time_at_berkeley_BART=657, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=610, destination='Mountain & Moraga', end_time=680, time_at_berkeley_BART=634, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=617, destination='San Pablo & Marin', end_time=686, time_at_berkeley_BART=670, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=625, destination='Mountain & Moraga', end_time=695, time_at_berkeley_BART=649, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=632, destination='San Pablo & Marin', end_time=701, time_at_berkeley_BART=685, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=640, destination='Mountain & Moraga', end_time=710, time_at_berkeley_BART=664, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=647, destination='San Pablo & Marin', end_time=716, time_at_berkeley_BART=700, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=655, destination='Mountain & Moraga', end_time=725, time_at_berkeley_BART=679, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=662, destination='San Pablo & Marin', end_time=731, time_at_berkeley_BART=715, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=670, destination='Mountain & Moraga', end_time=740, time_at_berkeley_BART=694, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=676, destination='San Pablo & Marin', end_time=745, time_at_berkeley_BART=729, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=685, destination='Mountain & Moraga', end_time=755, time_at_berkeley_BART=709, task_direction='SB', task_duration=70),
#  BusTask(origin='Mountain & Moraga', start_time=692, destination='San Pablo & Marin', end_time=761, time_at_berkeley_BART=745, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=699, destination='Mountain & Moraga', end_time=771, time_at_berkeley_BART=722, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=707, destination='San Pablo & Marin', end_time=776, time_at_berkeley_BART=760, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=714, destination='Mountain & Moraga', end_time=786, time_at_berkeley_BART=737, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=722, destination='San Pablo & Marin', end_time=791, time_at_berkeley_BART=775, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=729, destination='Mountain & Moraga', end_time=801, time_at_berkeley_BART=752, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=737, destination='San Pablo & Marin', end_time=806, time_at_berkeley_BART=790, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=744, destination='Mountain & Moraga', end_time=816, time_at_berkeley_BART=767, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=752, destination='San Pablo & Marin', end_time=821, time_at_berkeley_BART=805, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=758, destination='Mountain & Moraga', end_time=830, time_at_berkeley_BART=781, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=767, destination='San Pablo & Marin', end_time=836, time_at_berkeley_BART=820, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=774, destination='Mountain & Moraga', end_time=846, time_at_berkeley_BART=797, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=783, destination='San Pablo & Marin', end_time=852, time_at_berkeley_BART=836, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=789, destination='Mountain & Moraga', end_time=861, time_at_berkeley_BART=812, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=798, destination='San Pablo & Marin', end_time=867, time_at_berkeley_BART=851, task_direction='NB', task_duration=69),
#  BusTask(origin='San Pablo & Marin', start_time=804, destination='Mountain & Moraga', end_time=876, time_at_berkeley_BART=827, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=813, destination='San Pablo & Marin', end_time=885, time_at_berkeley_BART=868, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=819, destination='Mountain & Moraga', end_time=891, time_at_berkeley_BART=842, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=828, destination='San Pablo & Marin', end_time=900, time_at_berkeley_BART=883, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=834, destination='Mountain & Moraga', end_time=906, time_at_berkeley_BART=857, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=842, destination='San Pablo & Marin', end_time=914, time_at_berkeley_BART=897, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=849, destination='Mountain & Moraga', end_time=921, time_at_berkeley_BART=872, task_direction='SB', task_duration=72),
#  BusTask(origin='Mountain & Moraga', start_time=858, destination='San Pablo & Marin', end_time=930, time_at_berkeley_BART=913, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=864, destination='Mountain & Moraga', end_time=940, time_at_berkeley_BART=888, task_direction='SB', task_duration=76),
#  BusTask(origin='Mountain & Moraga', start_time=873, destination='San Pablo & Marin', end_time=945, time_at_berkeley_BART=928, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=879, destination='Mountain & Moraga', end_time=955, time_at_berkeley_BART=903, task_direction='SB', task_duration=76),
#  BusTask(origin='Mountain & Moraga', start_time=888, destination='San Pablo & Marin', end_time=960, time_at_berkeley_BART=943, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=893, destination='Mountain & Moraga', end_time=969, time_at_berkeley_BART=917, task_direction='SB', task_duration=76),
#  BusTask(origin='Mountain & Moraga', start_time=903, destination='San Pablo & Marin', end_time=975, time_at_berkeley_BART=958, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=906, destination='Mountain & Moraga', end_time=982, time_at_berkeley_BART=930, task_direction='SB', task_duration=76),
#  BusTask(origin='Mountain & Moraga', start_time=918, destination='San Pablo & Marin', end_time=990, time_at_berkeley_BART=973, task_direction='NB', task_duration=72),
#  BusTask(origin='San Pablo & Marin', start_time=919, destination='Mountain & Moraga', end_time=995, time_at_berkeley_BART=943, task_direction='SB', task_duration=76),
#  BusTask(origin='Mountain & Moraga', start_time=933, destination='San Pablo & Marin', end_time=1010, time_at_berkeley_BART=991, task_direction='NB', task_duration=77),
#  BusTask(origin='San Pablo & Marin', start_time=935, destination='Mountain & Moraga', end_time=1011, time_at_berkeley_BART=959, task_direction='SB', task_duration=76),
#  BusTask(origin='San Pablo & Marin', start_time=951, destination='Mountain & Moraga', end_time=1030, time_at_berkeley_BART=976, task_direction='SB', task_duration=79),
#  BusTask(origin='Mountain & Moraga', start_time=952, destination='San Pablo & Marin', end_time=1029, time_at_berkeley_BART=1010, task_direction='NB', task_duration=77),
#  BusTask(origin='San Pablo & Marin', start_time=966, destination='Mountain & Moraga', end_time=1045, time_at_berkeley_BART=991, task_direction='SB', task_duration=79),
#  BusTask(origin='Mountain & Moraga', start_time=967, destination='San Pablo & Marin', end_time=1044, time_at_berkeley_BART=1025, task_direction='NB', task_duration=77),
#  BusTask(origin='Mountain & Moraga', start_time=981, destination='San Pablo & Marin', end_time=1058, time_at_berkeley_BART=1039, task_direction='NB', task_duration=77),
#  BusTask(origin='San Pablo & Marin', start_time=982, destination='Mountain & Moraga', end_time=1061, time_at_berkeley_BART=1007, task_direction='SB', task_duration=79),
#  BusTask(origin='Mountain & Moraga', start_time=994, destination='San Pablo & Marin', end_time=1071, time_at_berkeley_BART=1052, task_direction='NB', task_duration=77),
#  BusTask(origin='San Pablo & Marin', start_time=998, destination='Mountain & Moraga', end_time=1077, time_at_berkeley_BART=1023, task_direction='SB', task_duration=79),
#  BusTask(origin='Mountain & Moraga', start_time=1007, destination='San Pablo & Marin', end_time=1080, time_at_berkeley_BART=1063, task_direction='NB', task_duration=73),
#  BusTask(origin='San Pablo & Marin', start_time=1013, destination='Mountain & Moraga', end_time=1092, time_at_berkeley_BART=1038, task_direction='SB', task_duration=79),
#  BusTask(origin='Mountain & Moraga', start_time=1023, destination='San Pablo & Marin', end_time=1096, time_at_berkeley_BART=1079, task_direction='NB', task_duration=73),
#  BusTask(origin='San Pablo & Marin', start_time=1029, destination='Mountain & Moraga', end_time=1108, time_at_berkeley_BART=1054, task_direction='SB', task_duration=79),
#  BusTask(origin='Mountain & Moraga', start_time=1042, destination='San Pablo & Marin', end_time=1115, time_at_berkeley_BART=1098, task_direction='NB', task_duration=73),
#  BusTask(origin='San Pablo & Marin', start_time=1045, destination='Mountain & Moraga', end_time=1124, time_at_berkeley_BART=1070, task_direction='SB', task_duration=79),
#  BusTask(origin='Mountain & Moraga', start_time=1057, destination='San Pablo & Marin', end_time=1130, time_at_berkeley_BART=1113, task_direction='NB', task_duration=73),
#  BusTask(origin='San Pablo & Marin', start_time=1061, destination='Mountain & Moraga', end_time=1136, time_at_berkeley_BART=1085, task_direction='SB', task_duration=75),
#  BusTask(origin='Mountain & Moraga', start_time=1073, destination='San Pablo & Marin', end_time=1146, time_at_berkeley_BART=1129, task_direction='NB', task_duration=73),
#  BusTask(origin='San Pablo & Marin', start_time=1083, destination='Mountain & Moraga', end_time=1158, time_at_berkeley_BART=1107, task_direction='SB', task_duration=75),
#  BusTask(origin='Mountain & Moraga', start_time=1089, destination='San Pablo & Marin', end_time=1162, time_at_berkeley_BART=1145, task_direction='NB', task_duration=73),
#  BusTask(origin='San Pablo & Marin', start_time=1095, destination='Mountain & Moraga', end_time=1170, time_at_berkeley_BART=1119, task_direction='SB', task_duration=75),
#  BusTask(origin='Mountain & Moraga', start_time=1104, destination='San Pablo & Marin', end_time=1177, time_at_berkeley_BART=1160, task_direction='NB', task_duration=73),
#  BusTask(origin='San Pablo & Marin', start_time=1111, destination='Mountain & Moraga', end_time=1186, time_at_berkeley_BART=1135, task_direction='SB', task_duration=75),
#  BusTask(origin='Mountain & Moraga', start_time=1120, destination='San Pablo & Marin', end_time=1185, time_at_berkeley_BART=1170, task_direction='NB', task_duration=65),
#  BusTask(origin='San Pablo & Marin', start_time=1128, destination='Mountain & Moraga', end_time=1196, time_at_berkeley_BART=1150, task_direction='SB', task_duration=68),
#  BusTask(origin='Mountain & Moraga', start_time=1136, destination='San Pablo & Marin', end_time=1201, time_at_berkeley_BART=1186, task_direction='NB', task_duration=65),
#  BusTask(origin='San Pablo & Marin', start_time=1143, destination='Mountain & Moraga', end_time=1211, time_at_berkeley_BART=1165, task_direction='SB', task_duration=68),
#  BusTask(origin='Mountain & Moraga', start_time=1148, destination='San Pablo & Marin', end_time=1213, time_at_berkeley_BART=1198, task_direction='NB', task_duration=65),
#  BusTask(origin='San Pablo & Marin', start_time=1162, destination='Mountain & Moraga', end_time=1230, time_at_berkeley_BART=1184, task_direction='SB', task_duration=68),
#  BusTask(origin='Mountain & Moraga', start_time=1170, destination='San Pablo & Marin', end_time=1235, time_at_berkeley_BART=1220, task_direction='NB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1182, destination='San Pablo & Marin', end_time=1247, time_at_berkeley_BART=1232, task_direction='NB', task_duration=65),
#  BusTask(origin='San Pablo & Marin', start_time=1182, destination='Mountain & Moraga', end_time=1250, time_at_berkeley_BART=1204, task_direction='SB', task_duration=68),
#  BusTask(origin='San Pablo & Marin', start_time=1202, destination='Mountain & Moraga', end_time=1270, time_at_berkeley_BART=1224, task_direction='SB', task_duration=68),
#  BusTask(origin='Mountain & Moraga', start_time=1208, destination='San Pablo & Marin', end_time=1270, time_at_berkeley_BART=1255, task_direction='NB', task_duration=62),
#  BusTask(origin='Mountain & Moraga', start_time=1223, destination='San Pablo & Marin', end_time=1285, time_at_berkeley_BART=1270, task_direction='NB', task_duration=62),
#  BusTask(origin='San Pablo & Marin', start_time=1226, destination='Mountain & Moraga', end_time=1291, time_at_berkeley_BART=1248, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1242, destination='San Pablo & Marin', end_time=1304, time_at_berkeley_BART=1289, task_direction='NB', task_duration=62),
#  BusTask(origin='San Pablo & Marin', start_time=1249, destination='Mountain & Moraga', end_time=1314, time_at_berkeley_BART=1271, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1262, destination='San Pablo & Marin', end_time=1324, time_at_berkeley_BART=1309, task_direction='NB', task_duration=62),
#  BusTask(origin='San Pablo & Marin', start_time=1267, destination='Mountain & Moraga', end_time=1332, time_at_berkeley_BART=1289, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1282, destination='San Pablo & Marin', end_time=1344, time_at_berkeley_BART=1329, task_direction='NB', task_duration=62),
#  BusTask(origin='San Pablo & Marin', start_time=1287, destination='Mountain & Moraga', end_time=1352, time_at_berkeley_BART=1309, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1303, destination='San Pablo & Marin', end_time=1365, time_at_berkeley_BART=1350, task_direction='NB', task_duration=62),
#  BusTask(origin='San Pablo & Marin', start_time=1307, destination='Mountain & Moraga', end_time=1372, time_at_berkeley_BART=1329, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1326, destination='San Pablo & Marin', end_time=1381, time_at_berkeley_BART=1368, task_direction='NB', task_duration=55),
#  BusTask(origin='San Pablo & Marin', start_time=1327, destination='Mountain & Moraga', end_time=1392, time_at_berkeley_BART=1349, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1356, destination='San Pablo & Marin', end_time=1411, time_at_berkeley_BART=1398, task_direction='NB', task_duration=55),
#  BusTask(origin='San Pablo & Marin', start_time=1357, destination='Mountain & Moraga', end_time=1422, time_at_berkeley_BART=1379, task_direction='SB', task_duration=65),
#  BusTask(origin='San Pablo & Marin', start_time=1387, destination='Mountain & Moraga', end_time=1452, time_at_berkeley_BART=1409, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1388, destination='San Pablo & Marin', end_time=1443, time_at_berkeley_BART=1430, task_direction='NB', task_duration=55),
#  BusTask(origin='San Pablo & Marin', start_time=1417, destination='Mountain & Moraga', end_time=1482, time_at_berkeley_BART=1439, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1418, destination='San Pablo & Marin', end_time=1473, time_at_berkeley_BART=1460, task_direction='NB', task_duration=55)]

# %%
# the first five BusTasks for Route 7 NB only, sorted by start time
[task for task in route_18_tasks if task.task_direction == 'NB'][0:5]
# Out:
# [BusTask(origin='Mountain & Moraga', start_time=321, destination='San Pablo & Marin', end_time=377, time_at_berkeley_BART=364, task_direction='NB', task_duration=56),
#  BusTask(origin='Mountain & Moraga', start_time=336, destination='San Pablo & Marin', end_time=392, time_at_berkeley_BART=379, task_direction='NB', task_duration=56),
#  BusTask(origin='Mountain & Moraga', start_time=351, destination='San Pablo & Marin', end_time=407, time_at_berkeley_BART=394, task_direction='NB', task_duration=56),
#  BusTask(origin='Mountain & Moraga', start_time=366, destination='San Pablo & Marin', end_time=422, time_at_berkeley_BART=409, task_direction='NB', task_duration=56),
#  BusTask(origin='Mountain & Moraga', start_time=382, destination='San Pablo & Marin', end_time=438, time_at_berkeley_BART=425, task_direction='NB', task_duration=56)]

# %%
# The last 5 BusTasks for Route 18. Notice the last 3 bus tasks end after midnight on the next day
route_18_tasks[-6:-1]
# Out:
# [BusTask(origin='Mountain & Moraga', start_time=1356, destination='San Pablo & Marin', end_time=1411, time_at_berkeley_BART=1398, task_direction='NB', task_duration=55),
#  BusTask(origin='San Pablo & Marin', start_time=1357, destination='Mountain & Moraga', end_time=1422, time_at_berkeley_BART=1379, task_direction='SB', task_duration=65),
#  BusTask(origin='San Pablo & Marin', start_time=1387, destination='Mountain & Moraga', end_time=1452, time_at_berkeley_BART=1409, task_direction='SB', task_duration=65),
#  BusTask(origin='Mountain & Moraga', start_time=1388, destination='San Pablo & Marin', end_time=1443, time_at_berkeley_BART=1430, task_direction='NB', task_duration=55),
#  BusTask(origin='San Pablo & Marin', start_time=1417, destination='Mountain & Moraga', end_time=1482, time_at_berkeley_BART=1439, task_direction='SB', task_duration=65)]

# %%
len(route_18_tasks)
# Out:
# 136

# %% [markdown]
# # Assigning Bus Tasks to Bus Runs
#
# We use Route 7 as an example for the remainder of the starter code. You will need to implement the following parts for route 18 and route 52 independently, and then for all 3 routes with bus tasks pooled together.
#
# The code block below iterates over the Bus Tasks for the route, creating one Bus Run at a time and greedily assigning as many Bus Tasks to it as is feasible. The greedy algorithm will be discussed in greater detail in class.
#
# For this starter code, we provide only a bare bones feasibility check -- a bus task can be assigned to a bus run either if the bus run is empty (i.e., first bus task of the run), or if the latest bus task in the bus run ends before the start time of the bus task we're considering *and* the latest bus task's destination and the origin of the bus task we're considering is the same location.
#
# For part B and C on the project, you will need to expand the feasibility check to incorporate the ability for Bus Runs to be assigned tasks to deadhead to a different location and/or the depot (in order to minimize dwell time).

# %%
#1 Bus Task Fesibility Check
##. Original
#Extend the starter version. A task is feasible if the bus can reach its origin in time for the scheduled departure.
def bus_task_feasibility_check(bus_run, bus_task):
    latest_task = bus_run.get_latest_task()
    if bus_run.is_empty():
        return True
    elif (latest_task.get_end_time() <= bus_task.get_start_time()) and (latest_task.get_destination() == bus_task.get_origin()):
        return True 
    else:
        return False
##. Extended

def bus_task_feasibility_check(bus_run, bus_task):

    latest_task = bus_run.get_latest_task()
    if bus_run.is_empty():
        return True
    elif (latest_task.get_end_time() <= bus_task.get_start_time()) and \
        (latest_task.get_destination() == bus_task.get_origin()):
        return True 
    elif (
        latest_task.get_end_time() <= bus_task.get_start_time()) and \
        (deadhead_time(latest_task.get_destination(),bus_task.get_origin()) <= \
         (bus_task.get_start_time()-latest_task.get_end_time())):
        return True
    else:
        return False
    
    #2 Bus Deadhead Feasibility Check
##Returns “True” if the next task starts at a different location than where the last task ended, meaning a deadhead leg is needed.
def bus_deadhead_feasibility_check(bus_run, bus_task):
    if bus_run.is_empty():
        return False
    latest_task = bus_run.get_latest_task()
    if (
        (latest_task.get_end_time() <= bus_task.get_start_time()) and \
        (deadhead_time(latest_task.get_destination(),bus_task.get_origin()) <= \
         (bus_task.get_start_time())-latest_task.get_end_time()) and \
        (latest_task.get_destination() != bus_task.get_origin())
    ):
        return True
    else:
        return False
    
#3 Add deadhead task
def add_deadhead(bus_run, bus_task):
    latest_task = bus_run.get_latest_task()
    
    origin = latest_task.get_destination()
    destination = bus_task.get_origin()
    
    start_time = latest_task.get_end_time()

    travel_time = deadhead_time(origin, destination)
    end_time = start_time + travel_time
    

    return BusTask(
        origin=origin,
        destination=destination,
        start_time=start_time,
        end_time=end_time,
        task_duration=travel_time,
        task_direction='deadhead' 
    )
    
    #Plot Gantt 

import matplotlib.pyplot as plt
from matplotlib.patches import Patch

def plot_bus_gantt(bus_runs):
    fig, ax = plt.subplots(figsize=(14, 7))
    
    # Updated Colors
    colors = {
        'NB': "#249c14",       
        'SB': "#e3ee0c",       
        'deadhead': "#959698", 
        'depot': "#090A0A"       
    }
    
    for i, bus_run in enumerate(bus_runs):
        for task in bus_run.get_task_list():
            start = task.get_start_time()
            duration = task.get_task_duration()
            
            # Check direction
            d = task.task_direction
            # Use the direction for color, default to deadhead
            color = colors.get(d, colors['deadhead'])
            
            ax.broken_barh([(start, duration)], (i - 0.4, 0.8), 
                           facecolors=color, edgecolor='black', linewidth=0.5)

    ax.set_yticks(range(len(bus_runs)))
    ax.set_yticklabels([f'Bus {i+1}' for i in range(len(bus_runs))])
    ax.set_xlabel('Time (Minutes from Midnight)')
    ax.set_title('Bus Runs Gantt Chart')
    
    legend_elements = [Patch(facecolor=colors[k], label=k) for k in colors]
    ax.legend(handles=legend_elements, title="Task Type", loc='upper right')
    
    plt.grid(axis='x', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
def calculate_bus_metrics(bus_runs):
    total_minutes = 0
    
    print(f"{'Run Index':<12} | {'Start':<8} | {'End':<8} | {'Duration (Hrs)':<15}")
    print("-" * 50)
    
    for i, run in enumerate(bus_runs):
        if run.is_empty():
            continue
            
        # Get the very first and very last tasks
        first_task = run.get_first_task()
        last_task = run.get_last_task()
        
        start_time = first_task.get_start_time()

        end_time = last_task.get_end_time()
        
        duration_mins = end_time - start_time
        duration_hrs = duration_mins / 60
        
        total_minutes += duration_mins
        
        print(f"Bus {i+1:<8} | {start_time:<8} | {end_time:<8} | {duration_hrs:<15.2f}")
    
    total_hours = total_minutes / 60
    print("-" * 50)
    print(f"TOTAL BUS HOURS: {total_hours:.2f} hours")
    return total_hours

# %%
bus_tasks = route_18_tasks
bus_tasks.sort(key=lambda x: x.get_start_time())

assigned_tasks = set()
unassigned_tasks = len(bus_tasks)
route_18_bus_runs = []
while unassigned_tasks:
    bus_run = BusRun()
    for task_idx, bus_task in enumerate(bus_tasks):
        if task_idx not in assigned_tasks:
            if bus_task_feasibility_check(bus_run, bus_task):
                if bus_deadhead_feasibility_check(bus_run, bus_task):
                    dh_leg = add_deadhead(bus_run,bus_task)
                    bus_run.add_back(dh_leg)
                bus_run.add_back(bus_task)
                assigned_tasks.add(task_idx)
                unassigned_tasks -= 1
    route_18_bus_runs.append(bus_run)
plot_bus_gantt(route_18_bus_runs)

# Run this after your scheduling loop
total_hrs = calculate_bus_metrics(route_18_bus_runs)
# Out:
# Run Index    | Start    | End      | Duration (Hrs)
# --------------------------------------------------
# Bus 1        | 315      | 1452     | 18.95
# Bus 2        | 321      | 1443     | 18.70
# Bus 3        | 330      | 1482     | 19.20
# Bus 4        | 336      | 1422     | 18.10
# Bus 5        | 346      | 1473     | 18.78
# Bus 6        | 351      | 1365     | 16.90
# Bus 7        | 357      | 1392     | 17.25
# Bus 8        | 366      | 1213     | 14.12
# Bus 9        | 443      | 1270     | 13.78
# Bus 10       | 449      | 1196     | 12.45
# Bus 11       | 458      | 1170     | 11.87
# --------------------------------------------------
# TOTAL BUS HOURS: 180.10 hours

# %% [markdown]
# For the barebones feasibility check, we find 3 bus runs are required to cover all of route 7's bus tasks.

# %%
len(route_18_bus_runs)
# Out:
# 11

# %%
bus_tasks = route_18_tasks
bus_tasks.sort(key=lambda x: x.get_start_time())

assigned_tasks = set()
unassigned_tasks = len(bus_tasks)
route_18_bus_runs = []
while unassigned_tasks:
    bus_run = BusRun()
    for task_idx, bus_task in enumerate(bus_tasks):
        if task_idx not in assigned_tasks:
            if bus_task_feasibility_check(bus_run, bus_task):
                if bus_deadhead_feasibility_check(bus_run, bus_task):
                    dh_leg = add_deadhead(bus_run,bus_task)
                    bus_run.add_back(dh_leg)
                bus_run.add_back(bus_task)
                assigned_tasks.add(task_idx)
                unassigned_tasks -= 1
    route_18_bus_runs.append(bus_run)

for bus_run in route_18_bus_runs:
    first_task = bus_run.get_first_task()
    time_to_depart_depot = first_task.get_start_time() - deadhead_time("Emeryville Depot", first_task.get_origin())
    depot_before_first_task = BusTask(origin="Emeryville Depot",
                                      start_time=time_to_depart_depot,
                                      destination=first_task.get_origin(),
                                      end_time=first_task.get_start_time())
    bus_run.add_front(depot_before_first_task)
    last_task = bus_run.get_last_task()
    time_to_arrive_depot = last_task.get_end_time() + deadhead_time(last_task.get_destination(), "Emeryville Depot")
    depot_after_last_task = BusTask(origin=last_task.get_destination(),
                                      start_time=last_task.get_end_time(),
                                      destination="Emeryville Depot",
                                      end_time=time_to_arrive_depot)
    bus_run.add_back(depot_after_last_task)
plot_bus_gantt(route_18_bus_runs)

# Run this after your scheduling loop
total_hrs = calculate_bus_metrics(route_18_bus_runs)
# Out:
# Run Index    | Start    | End      | Duration (Hrs)
# --------------------------------------------------
# Bus 1        | 305      | 1466     | 19.35
# Bus 2        | 307      | 1454     | 19.12
# Bus 3        | 320      | 1496     | 19.60
# Bus 4        | 322      | 1436     | 18.57
# Bus 5        | 336      | 1484     | 19.13
# Bus 6        | 337      | 1376     | 17.32
# Bus 7        | 347      | 1406     | 17.65
# Bus 8        | 352      | 1224     | 14.53
# Bus 9        | 433      | 1281     | 14.13
# Bus 10       | 435      | 1210     | 12.92
# Bus 11       | 448      | 1184     | 12.27
# --------------------------------------------------
# TOTAL BUS HOURS: 184.58 hours

# %% [markdown]
# Below is an example of viewing the Bus Tasks assigned to the first Bus Run for route 7.

# %%
# this is an example of one bus run for route 7
route_18_bus_runs[0].print_tasks()
# Out:
# BusTask(origin='Emeryville Depot', start_time=305, destination='San Pablo & Marin', end_time=315, time_at_berkeley_BART=None, task_direction=None, task_duration=10)
# BusTask(origin='San Pablo & Marin', start_time=315, destination='Mountain & Moraga', end_time=370, time_at_berkeley_BART=332, task_direction='SB', task_duration=55)
# BusTask(origin='Mountain & Moraga', start_time=382, destination='San Pablo & Marin', end_time=438, time_at_berkeley_BART=425, task_direction='NB', task_duration=56)
# BusTask(origin='San Pablo & Marin', start_time=440, destination='Mountain & Moraga', end_time=499, time_at_berkeley_BART=459, task_direction='SB', task_duration=59)
# BusTask(origin='Mountain & Moraga', start_time=511, destination='San Pablo & Marin', end_time=580, time_at_berkeley_BART=565, task_direction='NB', task_duration=69)
# BusTask(origin='San Pablo & Marin', start_time=580, destination='Mountain & Moraga', end_time=650, time_at_berkeley_BART=604, task_direction='SB', task_duration=70)
# BusTask(origin='Mountain & Moraga', start_time=662, destination='San Pablo & Marin', end_time=731, time_at_berkeley_BART=715, task_direction='NB', task_duration=69)
# BusTask(origin='San Pablo & Marin', start_time=744, destination='Mountain & Moraga', end_time=816, time_at_berkeley_BART=767, task_direction='SB', task_duration=72)
# BusTask(origin='Mountain & Moraga', start_time=828, destination='San Pablo & Marin', end_time=900, time_at_berkeley_BART=883, task_direction='NB', task_duration=72)
# BusTask(origin='San Pablo & Marin', start_time=906, destination='Mountain & Moraga', end_time=982, time_at_berkeley_BART=930, task_direction='SB', task_duration=76)
# BusTask(origin='Mountain & Moraga', start_time=994, destination='San Pablo & Marin', end_time=1071, time_at_berkeley_BART=1052, task_direction='NB', task_duration=77)
# BusTask(origin='San Pablo & Marin', start_time=1083, destination='Mountain & Moraga', end_time=1158, time_at_berkeley_BART=1107, task_direction='SB', task_duration=75)
# BusTask(origin='Mountain & Moraga', start_time=1170, destination='San Pablo & Marin', end_time=1235, time_at_berkeley_BART=1220, task_direction='NB', task_duration=65)
# BusTask(origin='San Pablo & Marin', start_time=1249, destination='Mountain & Moraga', end_time=1314, time_at_berkeley_BART=1271, task_direction='SB', task_duration=65)
# BusTask(origin='Mountain & Moraga', start_time=1326, destination='San Pablo & Marin', end_time=1381, time_at_berkeley_BART=1368, task_direction='NB', task_duration=55)
# BusTask(origin='San Pablo & Marin', start_time=1387, destination='Mountain & Moraga', end_time=1452, time_at_berkeley_BART=1409, task_direction='SB', task_duration=65)
# BusTask(origin='Mountain & Moraga', start_time=1452, destination='Emeryville Depot', end_time=1466, time_at_berkeley_BART=None, task_direction=None, task_duration=14)

# %% [markdown]
# Notice the BusRun above starts with the first task at Berkeley BART, and the last task of the run ends at Del Norte BART. However, all Bus Runs must start and end at the Emeryville Depot. Using the ```deadhead_time``` function, we can add a Bus Task from the depot to the first task origin  that lasts the deadheading time between the two locations, and add this as the first Bus Task for the run (using the ```bus_run.add_front``` function). We can do similarly to add a Bus Task from the final task destination to the depot, and add it to the end of the Bus Run.
#
# You may want to use something similar to the code below to implement deadheading between route termini and mid-run dwelling time at the depot.

# %%
def bus_depot_feasibility_check(bus_run, bus_task):
    if bus_run.is_empty():
        return False
    latest_task = bus_run.get_latest_task()
    depot = "Emeryville Depot"
    to_depot = deadhead_time(depot,bus_task.get_origin())
    from_depot = deadhead_time(depot,latest_task.get_destination())
    total_travel_required = to_depot + from_depot
    available_gap = bus_task.get_start_time() - latest_task.get_end_time()
    if (available_gap >= total_travel_required):
        return True
    else:
        return False
    
def add_depot_visit(bus_run, bus_task):
    latest_task = bus_run.get_latest_task()
    depot = "Emeryville Depot"
    
    # Task 1: Driving TO the depot
    to_depot_time = deadhead_time(latest_task.get_destination(), depot)
    trip_to_depot = BusTask(
        origin=latest_task.get_destination(),
        destination=depot,
        start_time=latest_task.get_end_time(),
        end_time=latest_task.get_end_time() + to_depot_time,
        task_direction='deadhead'
    )
    
    # Task 2: Driving FROM the depot to the next start
    from_depot_time = deadhead_time(depot, bus_task.get_origin())
    trip_from_depot = BusTask(
        origin=depot,
        destination=bus_task.get_origin(),
        start_time=bus_task.get_start_time() - from_depot_time,
        end_time=bus_task.get_start_time(),
        task_direction='deadhead'
    )

    wait_at_depot = BusTask(
        origin=depot,
        destination=depot,
        start_time=trip_to_depot.get_end_time(),
        end_time=trip_from_depot.get_start_time(),
        task_direction='depot'  
    )
    
    return trip_to_depot, wait_at_depot, trip_from_depot


def calculate_bus_metrics_depot(bus_runs):
    total_operating_mins = 0
    total_dwelling_mins = 0
    total_depot_mins = 0
    total_duration_mins = 0
    
    print(f"{'Run Index':<12} | {'Start':<8} | {'End':<8} | {'Dwell (Hrs)':<10}| {'Depot (Hrs)':<10}| {'Total (Hrs)':<15}")
    print("-" * 75)
    
    for i, run in enumerate(bus_runs):
        if run.is_empty():
            continue
            
        # Get the very first and very last tasks
        first_task = run.get_first_task()
        last_task = run.get_last_task()
        
        start_time = first_task.get_start_time()
        end_time = last_task.get_end_time()
        driving_mins = sum([task.get_task_duration() for task in run.get_task_list() if task.task_direction != 'depot'])
        depot_mins = sum([task.get_task_duration() for task in run.get_task_list() if task.task_direction == 'depot'])
        duration_mins = end_time - start_time
        dwelling_mins = duration_mins - driving_mins - depot_mins
        total_operating_mins += (driving_mins + dwelling_mins)
        total_dwelling_mins += dwelling_mins
        total_depot_mins += depot_mins
        total_duration_mins += duration_mins
        
        
        print(f"Bus {i+1:<8} | {start_time:<8} | {end_time:<8} |  {dwelling_mins/60:<10.2f} | {depot_mins/60:<10.2f} | {duration_mins/60:<10.2f}")
    
    print("-" * 75)
    print(f"Total Duration: {total_duration_mins / 60:.2f} hours")
    print(f"Total Paid Bus Hours: {total_operating_mins / 60:.2f} hours")
    print(f"Total Dwell Time:    {total_dwelling_mins / 60:.2f} hours")    
    print(f"Total Time at Depot:    {total_depot_mins / 60:.2f} hours")

    return total_operating_mins / 60

# %%
bus_tasks = route_18_tasks
bus_tasks.sort(key=lambda x: x.get_start_time())

assigned_tasks = set()
unassigned_tasks = len(bus_tasks)
route_18_bus_runs = []
while unassigned_tasks:
    bus_run = BusRun()
    for task_idx, bus_task in enumerate(bus_tasks):
        if task_idx not in assigned_tasks:
            if bus_task_feasibility_check(bus_run, bus_task):
                if bus_depot_feasibility_check(bus_run, bus_task):
                    to_depot, wait, from_depot = add_depot_visit(bus_run, bus_task)
                    bus_run.add_back(to_depot)       
                    bus_run.add_back(wait)  
                    bus_run.add_back(from_depot)
                
                elif bus_deadhead_feasibility_check(bus_run, bus_task):
                    dh_leg = add_deadhead(bus_run, bus_task)
                    bus_run.add_back(dh_leg)

                bus_run.add_back(bus_task)
                assigned_tasks.add(task_idx)
                unassigned_tasks -= 1
    route_18_bus_runs.append(bus_run)

for bus_run in route_18_bus_runs:
    first_task = bus_run.get_first_task()
    time_to_depart_depot = first_task.get_start_time() - deadhead_time("Emeryville Depot", first_task.get_origin())
    depot_before_first_task = BusTask(origin="Emeryville Depot",
                                      start_time=time_to_depart_depot,
                                      destination=first_task.get_origin(),
                                      end_time=first_task.get_start_time())
    bus_run.add_front(depot_before_first_task)
    last_task = bus_run.get_last_task()
    time_to_arrive_depot = last_task.get_end_time() + deadhead_time(last_task.get_destination(), "Emeryville Depot")
    depot_after_last_task = BusTask(origin=last_task.get_destination(),
                                      start_time=last_task.get_end_time(),
                                      destination="Emeryville Depot",
                                      end_time=time_to_arrive_depot)
    bus_run.add_back(depot_after_last_task)
    
plot_bus_gantt(route_18_bus_runs)
calculate_bus_metrics_depot(route_18_bus_runs)
# Out:
# Run Index    | Start    | End      | Dwell (Hrs)| Depot (Hrs)| Total (Hrs)
# ---------------------------------------------------------------------------
# Bus 1        | 305      | 1466     |  2.28       | 0.00       | 19.35
# Bus 2        | 307      | 1454     |  1.93       | 0.00       | 19.12
# Bus 3        | 320      | 1496     |  2.35       | 0.00       | 19.60
# Bus 4        | 322      | 1436     |  2.17       | 0.00       | 18.57
# Bus 5        | 336      | 1484     |  1.73       | 1.13       | 19.13
# Bus 6        | 337      | 1376     |  1.68       | 0.07       | 17.32
# Bus 7        | 347      | 1406     |  1.80       | 0.10       | 17.65
# Bus 8        | 352      | 1224     |  1.45       | 0.00       | 14.53
# Bus 9        | 433      | 1281     |  1.92       | 0.00       | 14.13
# Bus 10       | 435      | 1210     |  1.33       | 0.12       | 12.92
# Bus 11       | 448      | 1184     |  1.15       | 0.63       | 12.27
# ---------------------------------------------------------------------------
# Total Duration: 184.58 hours
# Total Paid Bus Hours: 182.53 hours
# Total Dwell Time:    19.80 hours
# Total Time at Depot:    2.05 hours
# 182.53333333333333

# %%
# now we see that the start and end tasks at the depot have been added
route_18_bus_runs[0].print_tasks()
# Out:
# BusTask(origin='Emeryville Depot', start_time=350, destination='Berkeley BART', end_time=360, time_at_berkeley_BART=None, task_direction=None, task_duration=10)
# BusTask(origin='Berkeley BART', start_time=360, destination='Del Norte BART', end_time=392, time_at_berkeley_BART=360, task_direction='NB', task_duration=32)
# BusTask(origin='Del Norte BART', start_time=405, destination='Berkeley BART', end_time=439, time_at_berkeley_BART=439, task_direction='SB', task_duration=34)
# BusTask(origin='Berkeley BART', start_time=439, destination='Emeryville Depot', end_time=449, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Emeryville Depot', start_time=449, destination='Emeryville Depot', end_time=462, time_at_berkeley_BART=None, task_direction='depot', task_duration=13)
# BusTask(origin='Emeryville Depot', start_time=462, destination='Berkeley BART', end_time=472, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Berkeley BART', start_time=472, destination='Del Norte BART', end_time=505, time_at_berkeley_BART=472, task_direction='NB', task_duration=33)
# BusTask(origin='Del Norte BART', start_time=525, destination='Berkeley BART', end_time=560, time_at_berkeley_BART=560, task_direction='SB', task_duration=35)
# BusTask(origin='Berkeley BART', start_time=560, destination='Emeryville Depot', end_time=570, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Emeryville Depot', start_time=570, destination='Emeryville Depot', end_time=584, time_at_berkeley_BART=None, task_direction='depot', task_duration=14)
# BusTask(origin='Emeryville Depot', start_time=584, destination='Berkeley BART', end_time=594, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Berkeley BART', start_time=594, destination='Del Norte BART', end_time=627, time_at_berkeley_BART=594, task_direction='NB', task_duration=33)
# BusTask(origin='Del Norte BART', start_time=645, destination='Berkeley BART', end_time=680, time_at_berkeley_BART=680, task_direction='SB', task_duration=35)
# BusTask(origin='Berkeley BART', start_time=680, destination='Emeryville Depot', end_time=690, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Emeryville Depot', start_time=690, destination='Emeryville Depot', end_time=704, time_at_berkeley_BART=None, task_direction='depot', task_duration=14)
# BusTask(origin='Emeryville Depot', start_time=704, destination='Berkeley BART', end_time=714, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Berkeley BART', start_time=714, destination='Del Norte BART', end_time=747, time_at_berkeley_BART=714, task_direction='NB', task_duration=33)
# BusTask(origin='Del Norte BART', start_time=765, destination='Berkeley BART', end_time=800, time_at_berkeley_BART=800, task_direction='SB', task_duration=35)
# BusTask(origin='Berkeley BART', start_time=800, destination='Emeryville Depot', end_time=810, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Emeryville Depot', start_time=810, destination='Emeryville Depot', end_time=825, time_at_berkeley_BART=None, task_direction='depot', task_duration=15)
# BusTask(origin='Emeryville Depot', start_time=825, destination='Berkeley BART', end_time=835, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Berkeley BART', start_time=835, destination='Del Norte BART', end_time=868, time_at_berkeley_BART=835, task_direction='NB', task_duration=33)
# BusTask(origin='Del Norte BART', start_time=885, destination='Berkeley BART', end_time=920, time_at_berkeley_BART=920, task_direction='SB', task_duration=35)
# BusTask(origin='Berkeley BART', start_time=920, destination='Emeryville Depot', end_time=930, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Emeryville Depot', start_time=930, destination='Emeryville Depot', end_time=946, time_at_berkeley_BART=None, task_direction='depot', task_duration=16)
# BusTask(origin='Emeryville Depot', start_time=946, destination='Berkeley BART', end_time=956, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Berkeley BART', start_time=956, destination='Del Norte BART', end_time=989, time_at_berkeley_BART=956, task_direction='NB', task_duration=33)
# BusTask(origin='Del Norte BART', start_time=1005, destination='Berkeley BART', end_time=1040, time_at_berkeley_BART=1040, task_direction='SB', task_duration=35)
# BusTask(origin='Berkeley BART', start_time=1040, destination='Emeryville Depot', end_time=1050, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Emeryville Depot', start_time=1050, destination='Emeryville Depot', end_time=1067, time_at_berkeley_BART=None, task_direction='depot', task_duration=17)
# BusTask(origin='Emeryville Depot', start_time=1067, destination='Berkeley BART', end_time=1077, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Berkeley BART', start_time=1077, destination='Del Norte BART', end_time=1110, time_at_berkeley_BART=1077, task_direction='NB', task_duration=33)
# BusTask(origin='Del Norte BART', start_time=1126, destination='Berkeley BART', end_time=1160, time_at_berkeley_BART=1160, task_direction='SB', task_duration=34)
# BusTask(origin='Berkeley BART', start_time=1160, destination='Emeryville Depot', end_time=1170, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Emeryville Depot', start_time=1170, destination='Emeryville Depot', end_time=1184, time_at_berkeley_BART=None, task_direction='depot', task_duration=14)
# BusTask(origin='Emeryville Depot', start_time=1184, destination='Berkeley BART', end_time=1194, time_at_berkeley_BART=None, task_direction='deadhead', task_duration=10)
# BusTask(origin='Berkeley BART', start_time=1194, destination='Del Norte BART', end_time=1226, time_at_berkeley_BART=1194, task_direction='NB', task_duration=32)
# BusTask(origin='Del Norte BART', start_time=1226, destination='Emeryville Depot', end_time=1243, time_at_berkeley_BART=None, task_direction=None, task_duration=17)

# %% [markdown]
# Ultimately, we want to find the bus-hrs spent in operation and dwelling (as the goal of the assignment is to minimize wasted dwell time). We can calculate the total operating time for route 7 by finding the start and end time for each Bus Run, taking the difference, and summing it over all Bus Runs. Total dwelling time can be found by subtracting the task duration for each Bus Task in each Bus Run from the operating time of each Bus Task, and summing over all Bus Runs.

# %%
# total operating and dwelling time
total_operating_time = 0
total_dwelling_time = 0
for bus_run in route_7_bus_runs:
    operating_time = bus_run.get_last_task().get_end_time() - bus_run.get_first_task().get_start_time()
    driving_time = sum([task.get_task_duration() for task in bus_run.get_task_list()])
    dwelling_time = operating_time - driving_time
    total_operating_time += operating_time
    total_dwelling_time += dwelling_time

print(f"Total operating time: {total_operating_time/60}")
print(f"Total dwelling time: {total_dwelling_time/60}")
# Out:
# Total operating time: 44.46666666666667
# Total dwelling time: 5.316666666666666

# %% [markdown]
# # Cutting Bus Runs into Driver Tasks
#
# Each Bus Run can be cut into Driver Tasks, which will later be assigned to form Driver Jobs. A Driver Task is the smallest portion of a Bus Run (i.e. collection of Bus Tasks) such that it starts and ends at one of the driver exchange points, Emeryville Depot and Berkeley BART.
#
# We provide a simple implementation that loops through the the Bus Tasks for each Bus Run and checks if the bus task ends at a driver exchange point. We know the first task of each bus run starts at a driver exchange point, so the start time and origin are recorded. Then, each proceeding Bus Task is checked. If the bus task Ends at an exchange point, then a Driver Task is created, started from the recorded start time and origin and ending at the ending Bus Task's end time and destination. The Driver Task is saved, and then the variables for the recorded start time and origin (for the next Driver Task) are updated to equal the previous ending Bus Task's end time and destination. The loop proceeds until all Bus Tasks in a Bus Run have been collected to form Driver Tasks.
#
# To simplify calculations later on, the time a driver spends driving (as opposed to dwelling) is calculated for each Driver Task.
#
# *Note:* Our implementation *does not* include the possibility of mid-Bus Task driver exchanges, i.e., route 18 Bus Tasks have Berkeley BART as a location along its route but not as a route terminus. Your implementations involving route 18 should allow for the possibility of a Driver Task to start or end in the middle of a route 18 Bus Task, as well as when Berkeley BART is a route terminus or the Emeryville Depot.

# %%
route_7_driver_tasks = []
driver_exchange_points = {"Emeryville Depot", "Berkeley BART"}
for bus_run in route_7_bus_runs:
    start_time = bus_run.get_first_task().get_start_time()
    origin_location = bus_run.get_first_task().get_origin()
    driver_driving_time = 0
    for bus_task in bus_run.get_task_list():
        driver_driving_time += bus_task.get_task_duration()
        if bus_task.get_destination() in driver_exchange_points:
            driver_task = DriverTask(origin=origin_location,
                                     start_time=start_time,
                                     destination=bus_task.get_destination(),
                                     end_time=bus_task.get_end_time(),
                                     time_spent_driving=driver_driving_time)
            route_7_driver_tasks.append(driver_task)
            start_time = bus_task.get_end_time()
            origin_location = bus_task.get_destination()
            driver_driving_time = 0

# %%
# All driver tasks for route 7
route_7_driver_tasks
# Out:
# [DriverTask(origin='Emeryville Depot', start_time=350, destination='Berkeley BART', end_time=360, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=360, destination='Berkeley BART', end_time=439, time_spent_driving=66),
#  DriverTask(origin='Berkeley BART', start_time=439, destination='Emeryville Depot', end_time=449, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=449, destination='Emeryville Depot', end_time=462, time_spent_driving=13),
#  DriverTask(origin='Emeryville Depot', start_time=462, destination='Berkeley BART', end_time=472, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=472, destination='Berkeley BART', end_time=560, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=560, destination='Emeryville Depot', end_time=570, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=570, destination='Emeryville Depot', end_time=584, time_spent_driving=14),
#  DriverTask(origin='Emeryville Depot', start_time=584, destination='Berkeley BART', end_time=594, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=594, destination='Berkeley BART', end_time=680, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=680, destination='Emeryville Depot', end_time=690, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=690, destination='Emeryville Depot', end_time=704, time_spent_driving=14),
#  DriverTask(origin='Emeryville Depot', start_time=704, destination='Berkeley BART', end_time=714, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=714, destination='Berkeley BART', end_time=800, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=800, destination='Emeryville Depot', end_time=810, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=810, destination='Emeryville Depot', end_time=825, time_spent_driving=15),
#  DriverTask(origin='Emeryville Depot', start_time=825, destination='Berkeley BART', end_time=835, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=835, destination='Berkeley BART', end_time=920, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=920, destination='Emeryville Depot', end_time=930, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=930, destination='Emeryville Depot', end_time=946, time_spent_driving=16),
#  DriverTask(origin='Emeryville Depot', start_time=946, destination='Berkeley BART', end_time=956, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=956, destination='Berkeley BART', end_time=1040, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=1040, destination='Emeryville Depot', end_time=1050, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=1050, destination='Emeryville Depot', end_time=1067, time_spent_driving=17),
#  DriverTask(origin='Emeryville Depot', start_time=1067, destination='Berkeley BART', end_time=1077, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=1077, destination='Berkeley BART', end_time=1160, time_spent_driving=67),
#  DriverTask(origin='Berkeley BART', start_time=1160, destination='Emeryville Depot', end_time=1170, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=1170, destination='Emeryville Depot', end_time=1184, time_spent_driving=14),
#  DriverTask(origin='Emeryville Depot', start_time=1184, destination='Berkeley BART', end_time=1194, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=1194, destination='Emeryville Depot', end_time=1243, time_spent_driving=49),
#  DriverTask(origin='Emeryville Depot', start_time=352, destination='Berkeley BART', end_time=404, time_spent_driving=52),
#  DriverTask(origin='Berkeley BART', start_time=404, destination='Emeryville Depot', end_time=414, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=414, destination='Emeryville Depot', end_time=417, time_spent_driving=3),
#  DriverTask(origin='Emeryville Depot', start_time=417, destination='Berkeley BART', end_time=470, time_spent_driving=53),
#  DriverTask(origin='Berkeley BART', start_time=470, destination='Berkeley BART', end_time=520, time_spent_driving=50),
#  DriverTask(origin='Berkeley BART', start_time=520, destination='Emeryville Depot', end_time=530, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=530, destination='Emeryville Depot', end_time=545, time_spent_driving=15),
#  DriverTask(origin='Emeryville Depot', start_time=545, destination='Berkeley BART', end_time=555, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=555, destination='Berkeley BART', end_time=640, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=640, destination='Emeryville Depot', end_time=650, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=650, destination='Emeryville Depot', end_time=664, time_spent_driving=14),
#  DriverTask(origin='Emeryville Depot', start_time=664, destination='Berkeley BART', end_time=674, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=674, destination='Berkeley BART', end_time=760, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=760, destination='Emeryville Depot', end_time=770, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=770, destination='Emeryville Depot', end_time=784, time_spent_driving=14),
#  DriverTask(origin='Emeryville Depot', start_time=784, destination='Berkeley BART', end_time=794, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=794, destination='Berkeley BART', end_time=880, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=880, destination='Emeryville Depot', end_time=890, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=890, destination='Emeryville Depot', end_time=906, time_spent_driving=16),
#  DriverTask(origin='Emeryville Depot', start_time=906, destination='Berkeley BART', end_time=916, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=916, destination='Berkeley BART', end_time=1000, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=1000, destination='Emeryville Depot', end_time=1010, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=1010, destination='Emeryville Depot', end_time=1027, time_spent_driving=17),
#  DriverTask(origin='Emeryville Depot', start_time=1027, destination='Berkeley BART', end_time=1037, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=1037, destination='Berkeley BART', end_time=1120, time_spent_driving=67),
#  DriverTask(origin='Berkeley BART', start_time=1120, destination='Emeryville Depot', end_time=1130, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=1130, destination='Emeryville Depot', end_time=1147, time_spent_driving=17),
#  DriverTask(origin='Emeryville Depot', start_time=1147, destination='Berkeley BART', end_time=1157, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=1157, destination='Berkeley BART', end_time=1234, time_spent_driving=66),
#  DriverTask(origin='Berkeley BART', start_time=1234, destination='Emeryville Depot', end_time=1244, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=387, destination='Berkeley BART', end_time=397, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=397, destination='Emeryville Depot', end_time=446, time_spent_driving=49),
#  DriverTask(origin='Emeryville Depot', start_time=446, destination='Emeryville Depot', end_time=503, time_spent_driving=57),
#  DriverTask(origin='Emeryville Depot', start_time=503, destination='Berkeley BART', end_time=513, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=513, destination='Berkeley BART', end_time=600, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=600, destination='Emeryville Depot', end_time=610, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=610, destination='Emeryville Depot', end_time=624, time_spent_driving=14),
#  DriverTask(origin='Emeryville Depot', start_time=624, destination='Berkeley BART', end_time=634, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=634, destination='Berkeley BART', end_time=720, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=720, destination='Emeryville Depot', end_time=730, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=730, destination='Emeryville Depot', end_time=744, time_spent_driving=14),
#  DriverTask(origin='Emeryville Depot', start_time=744, destination='Berkeley BART', end_time=754, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=754, destination='Berkeley BART', end_time=840, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=840, destination='Emeryville Depot', end_time=850, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=850, destination='Emeryville Depot', end_time=865, time_spent_driving=15),
#  DriverTask(origin='Emeryville Depot', start_time=865, destination='Berkeley BART', end_time=875, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=875, destination='Berkeley BART', end_time=960, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=960, destination='Emeryville Depot', end_time=970, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=970, destination='Emeryville Depot', end_time=986, time_spent_driving=16),
#  DriverTask(origin='Emeryville Depot', start_time=986, destination='Berkeley BART', end_time=996, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=996, destination='Berkeley BART', end_time=1080, time_spent_driving=68),
#  DriverTask(origin='Berkeley BART', start_time=1080, destination='Emeryville Depot', end_time=1090, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=1090, destination='Emeryville Depot', end_time=1107, time_spent_driving=17),
#  DriverTask(origin='Emeryville Depot', start_time=1107, destination='Berkeley BART', end_time=1117, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=1117, destination='Berkeley BART', end_time=1200, time_spent_driving=66),
#  DriverTask(origin='Berkeley BART', start_time=1200, destination='Emeryville Depot', end_time=1210, time_spent_driving=10),
#  DriverTask(origin='Emeryville Depot', start_time=427, destination='Berkeley BART', end_time=437, time_spent_driving=10),
#  DriverTask(origin='Berkeley BART', start_time=437, destination='Emeryville Depot', end_time=487, time_spent_driving=50)]

# %% [markdown]
# # Assigning Driver Tasks to Driver Jobs
#
# A similar procedure as Bus Task assignment is used to greedily assign Driver Tasks to Driver Jobs. A Driver Job is simply a collection of Driver Tasks that one driver would complete in a work shift. However, in addition to checking that a Driver Task can feasibly be added to a Driver Job (by checking start and end locations and times), we must make sure that adding the task would not make the Driver Job go over the maximum shift length. In the code provided, a shift length of 8 hours is used.
#
# A Driver Task puts a Driver Job into overtime if: it is the first Driver Task of the Driver Job and it has a duration greater than the maximum shift length;  if adding the Driver Task to the existing Driver Job makes the job duration greater than the shift length; or if adding the Driver Task would create a split shift (i.e., working in non-consecutive parts of the day with a total working duration greater than the maximum shift length).
#
# You will need to expand the code provided to allow for drivers to potentially work overtime (if it would be cheaper than hiring a new driver for a full 8 hour shift), and to support the different types of shift lengths described in the assignment.

# %%
def would_make_driver_job_overtime(driver_job, driver_task):
    if driver_job.is_empty():
        return driver_task.get_task_duration() > driver_job.get_shift_length()
    else:
        # assume no split shifts
        return ((driver_job.get_last_task().get_end_time() - driver_job.get_first_task().get_start_time()) + driver_task.get_task_duration() > driver_job.get_shift_length()) or \
                (driver_task.get_end_time() - driver_job.get_first_task().get_start_time() > driver_job.get_shift_length())

def driver_task_feasibility_check(driver_job, driver_task):
    latest_task = driver_job.get_latest_task()
    if driver_job.is_empty():
        return True
    elif (latest_task.get_end_time() <= driver_task.get_start_time()) and (latest_task.get_destination() == driver_task.get_origin()):
        return True 
    else:
        return False



driver_tasks = sorted(route_7_driver_tasks, key=lambda x: x.get_start_time(), reverse=False)
assigned_tasks = set()
unassigned_tasks = len(driver_tasks)
route_7_driver_jobs = []
while unassigned_tasks:
    driver_job = DriverJob(shift_length=8)
    for task_idx, driver_task in enumerate(driver_tasks):
        if task_idx not in assigned_tasks:
            if would_make_driver_job_overtime(driver_job, driver_task) == False:
                if driver_task_feasibility_check(driver_job, driver_task):
                    driver_job.add_back(driver_task)
                    assigned_tasks.add(task_idx)
                    unassigned_tasks -= 1
    route_7_driver_jobs.append(driver_job)

# %% [markdown]
# We can see below that 7 drivers will be needed to cover the route 7 driver jobs.

# %%
len(route_7_driver_jobs)
# Out:
# 7

# %%
# Example of one route 7 driver job
route_7_driver_jobs[0].print_tasks()
# Out:
# DriverTask(origin='Emeryville Depot', start_time=350, destination='Berkeley BART', end_time=360, time_spent_driving=10)
# DriverTask(origin='Berkeley BART', start_time=360, destination='Berkeley BART', end_time=439, time_spent_driving=66)
# DriverTask(origin='Berkeley BART', start_time=439, destination='Berkeley BART', end_time=560, time_spent_driving=68)
# DriverTask(origin='Berkeley BART', start_time=560, destination='Berkeley BART', end_time=680, time_spent_driving=68)
# DriverTask(origin='Berkeley BART', start_time=680, destination='Berkeley BART', end_time=800, time_spent_driving=68)

# %% [markdown]
# The assignment asks for the driver hours wasted (i.e., total time drivers do not spend driving) and the cost for covering the runs. You can see below that 17.46 driver-hours are wasted and it will cost $1086.67 to cover all of the runs.

# %%
total_wasted_time = 0
total_running_time = 0
for driver_job in route_7_driver_jobs:
    for driver_task in driver_job.get_task_list():
        running_time = driver_task.get_end_time() - driver_task.get_start_time()
        wasted_time = running_time - driver_task.get_time_spent_driving()
        total_running_time += running_time
        total_wasted_time += wasted_time

print(f"Total wasted time: {total_wasted_time/60} driver-hrs")
print(f"Total cost to cover Route 7 runs: ${len(route_7_driver_jobs)*8*25}")
# Out:
# Total wasted time: 17.466666666666665 driver-hrs
# Total cost to cover Route 7 runs: $1400
